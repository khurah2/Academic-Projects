# %% [markdown]
# Getting Data

# %%
import yfinance as yf

# %%
import yfinance as yf
data = yf.download("AMZN", period="36mo")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Data Format

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print(data.shape)
# Out:
# (754, 6)

# %%
data.to_csv("/Users/shubham/Desktop/compsci_4zp6a_capstone/content/AMZN_demo.csv", sep='\t')

# %% [markdown]
# Data Cleaning

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['Close'][0:10]
data['Close'][-1:]
# Out:
# Date
# 2024-04-01 00:00:00-04:00    180.419998
# Name: Close, dtype: float64

# %%
data.T
# Out:
# Date       2021-04-01 00:00:00-04:00  2021-04-05 00:00:00-04:00  \
# Open                    1.558970e+02               1.586500e+02
# High                    1.581220e+02               1.617980e+02
# Low                     1.557775e+02               1.580620e+02
# Close                   1.580500e+02               1.613365e+02
# Adj Close               1.580500e+02               1.613365e+02
# Volume                  5.880600e+07               6.669800e+07
#
# Date       2021-04-06 00:00:00-04:00  2021-04-07 00:00:00-04:00  \
# Open                    1.611875e+02               1.616900e+02
# High                    1.623655e+02               1.651805e+02
# Low                     1.608520e+02               1.611825e+02
# Close                   1.611910e+02               1.639695e+02
# Adj Close               1.611910e+02               1.639695e+02
# Volume                  5.075600e+07               6.692400e+07
#
# Date       2021-04-08 00:00:00-04:00  2021-04-09 00:00:00-04:00  \
# Open                    1.655450e+02               1.652350e+02
# High                    1.662250e+02               1.686100e+02
# Low                     1.646000e+02               1.644450e+02
# Close                   1.649650e+02               1.686100e+02
# Adj Close               1.649650e+02               1.686100e+02
# Volume                  5.624200e+07               8.683000e+07
#
# Date       2021-04-12 00:00:00-04:00  2021-04-13 00:00:00-04:00  \
# Open                    1.677605e+02               1.700425e+02
# High                    1.697520e+02               1.716000e+02
# Low                     1.675575e+02               1.697815e+02
# Close                   1.689695e+02               1.700000e+02
# Adj Close               1.689695e+02               1.700000e+02
# Volume                  6.563600e+07               6.631600e+07
#
# Date       2021-04-14 00:00:00-04:00  2021-04-15 00:00:00-04:00  ...  \
# Open                    1.702020e+02               1.685500e+02  ...
# High                    1.702065e+02               1.698500e+02  ...
# Low                     1.663000e+02               1.676000e+02  ...
# Close                   1.666500e+02               1.689545e+02  ...
# Adj Close               1.666500e+02               1.689545e+02  ...
# Volume                  6.290400e+07               6.467200e+07  ...
#
# Date       2024-03-18 00:00:00-04:00  2024-03-19 00:00:00-04:00  \
# Open                    1.758000e+02               1.742200e+02
# High                    1.766900e+02               1.760900e+02
# Low                     1.742800e+02               1.735200e+02
# Close                   1.744800e+02               1.759000e+02
# Adj Close               1.744800e+02               1.759000e+02
# Volume                  3.125070e+07               2.688090e+07
#
# Date       2024-03-20 00:00:00-04:00  2024-03-21 00:00:00-04:00  \
# Open                    1.761400e+02               1.799900e+02
# High                    1.785300e+02               1.814200e+02
# Low                     1.746400e+02               1.781500e+02
# Close                   1.781500e+02               1.781500e+02
# Adj Close               1.781500e+02               1.781500e+02
# Volume                  2.994720e+07               3.282430e+07
#
# Date       2024-03-22 00:00:00-04:00  2024-03-25 00:00:00-04:00  \
# Open                    1.777500e+02               1.780100e+02
# High                    1.792600e+02               1.809900e+02
# Low                     1.767500e+02               1.772400e+02
# Close                   1.788700e+02               1.797100e+02
# Adj Close               1.788700e+02               1.797100e+02
# Volume                  2.796410e+07               2.981550e+07
#
# Date       2024-03-26 00:00:00-04:00  2024-03-27 00:00:00-04:00  \
# Open                    1.801500e+02               1.798800e+02
# High                    1.804500e+02               1.800000e+02
# Low                     1.779500e+02               1.773100e+02
# Close                   1.783000e+02               1.798300e+02
# Adj Close               1.783000e+02               1.798300e+02
# Volume                  2.965900e+07               3.327260e+07
#
# Date       2024-03-28 00:00:00-04:00  2024-04-01 00:00:00-04:00
# Open                    1.801700e+02               1.807900e+02
# High                    1.817000e+02               1.830000e+02
# Low                     1.792600e+02               1.799600e+02
# Close                   1.803800e+02               1.804200e+02
# Adj Close               1.803800e+02               1.804200e+02
# Volume                  3.805160e+07               1.364711e+07
#
# [6 rows x 754 columns]

# %%
import numpy
import pandas as pd
import csv
from datetime import datetime

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/content/AMZN_demo.csv', newline='') as f:
    reader = csv.reader(f)
    data_list = list(reader)
   
data_list_clean=[]
list_clean=[]
k=0
print(str(data_list[0][0]))
for i in data_list[1:]:
  list_clean+=[str(i[0]).split("\t")]
  
for j in list_clean:
    
  date=(j[0][:10])
   
  a=[date]+[float(j[1])]+[float(j[2])]+[float(j[3])]+[float(j[4])]+[float(j[5])]+[float(j[6])]
  data_list_clean+=[a]
   

print(len(data_list))
print(len(data_list_clean))
# Out:
# Date	Open	High	Low	Close	Adj Close	Volume
# 755
# 754

# %%
df=pd.DataFrame(data_list_clean[1:],columns=data_list[0][0].split("\t"))
print(df.dtypes)
df_fil=df[['Date','Close']]

print(df_fil[:10])
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date       Close
# 0  2021-04-05  161.336502
# 1  2021-04-06  161.190994
# 2  2021-04-07  163.969498
# 3  2021-04-08  164.964996
# 4  2021-04-09  168.610001
# 5  2021-04-12  168.969498
# 6  2021-04-13  170.000000
# 7  2021-04-14  166.649994
# 8  2021-04-15  168.954498
# 9  2021-04-16  169.972000

# %%
print(data_list_clean)
# Out:
# [['2021-04-01', 155.89700317382812, 158.1219940185547, 155.77749633789062, 158.0500030517578, 158.0500030517578, 58806000.0], ['2021-04-05', 158.64999389648438, 161.79800415039062, 158.06199645996094, 161.3365020751953, 161.3365020751953, 66698000.0], ['2021-04-06', 161.1875, 162.36549377441406, 160.8520050048828, 161.1909942626953, 161.1909942626953, 50756000.0], ['2021-04-07', 161.69000244140625, 165.1804962158203, 161.1824951171875, 163.96949768066406, 163.96949768066406, 66924000.0], ['2021-04-08', 165.5449981689453, 166.22500610351562, 164.60000610351562, 164.96499633789062, 164.96499633789062, 56242000.0], ['2021-04-09', 165.23500061035156, 168.61000061035156, 164.44500732421875, 168.61000061035156, 168.61000061035156, 86830000.0], ['2021-04-12', 167.760498046875, 169.7519989013672, 167.5574951171875, 168.96949768066406, 168.96949768066406, 65636000.0], ['2021-04-13', 170.04249572753906, 171.60000610351562, 169.781494140625, 170.0, 170.0, 66316000.0], ['2021-04-14', 170.20199584960938, 170.2064971923828, 166.3000030517578, 166.64999389648438, 166.64999389648438, 62904000.0], ['2021-04-15', 168.5500030517578, 169.85000610351562, 167.60000610351562
py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Date']=df_fil['Date'].apply(str_to_datetime)

# %%
df_fil['Date']
# Out:
# 0     2021-04-05
# 1     2021-04-06
# 2     2021-04-07
# 3     2021-04-08
# 4     2021-04-09
#          ...
# 748   2024-03-25
# 749   2024-03-26
# 750   2024-03-27
# 751   2024-03-28
# 752   2024-04-01
# Name: Date, Length: 753, dtype: datetime64[ns]

# %%
df_fil.index=df_fil.pop('Date')
print(df_fil)
# Out:
#                  Close
# Date
# 2021-04-05  161.336502
# 2021-04-06  161.190994
# 2021-04-07  163.969498
# 2021-04-08  164.964996
# 2021-04-09  168.610001
# ...                ...
# 2024-03-25  179.710007
# 2024-03-26  178.300003
# 2024-03-27  179.830002
# 2024-03-28  180.380005
# 2024-04-01  180.419998
#
# [753 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df=df_fil
plt.plot(df.index, df['Close'])
print(df[:-10])
# Out:
#                  Close
# Date
# 2021-04-05  161.336502
# 2021-04-06  161.190994
# 2021-04-07  163.969498
# 2021-04-08  164.964996
# 2021-04-09  168.610001
# ...                ...
# 2024-03-11  171.960007
# 2024-03-12  175.389999
# 2024-03-13  176.559998
# 2024-03-14  178.750000
# 2024-03-15  174.419998
#
# [743 rows x 1 columns]

# %%
str(df_fil.index[-51])[:-9]
# Out:
# '2024-01-18'

# %% [markdown]
# Reshaping data for model

# %%
import numpy as np
window_size_n=60
startdate= str(df_fil.index[window_size_n])[:-9]
lastdate=str(df_fil.index[-1])[:-9]


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                startdate,
                                lastdate,
                                window_size_n)
windowed_df
# Out:
#     Target Date   Target-60   Target-59   Target-58   Target-57   Target-56  \
# 0    2021-06-29  161.336502  161.190994  163.969498  164.964996  168.610001
# 1    2021-06-30  161.190994  163.969498  164.964996  168.610001  168.969498
# 2    2021-07-01  163.969498  164.964996  168.610001  168.969498  170.000000
# 3    2021-07-02  164.964996  168.610001  168.969498  170.000000  166.649994
# 4    2021-07-06  168.610001  168.969498  170.000000  166.649994  168.954498
# ..          ...         ...         ...         ...         ...         ...
# 688  2024-03-25  153.339996  153.380005  151.940002  149.929993  148.470001
# 689  2024-03-26  153.380005  151.940002  149.929993  148.470001  144.570007
# 690  2024-03-27  151.940002  149.929993  148.470001  144.570007  145.240005
# 691  2024-03-28  149.929993  148.470001  144.570007  145.240005  149.100006
# 692  2024-04-01  148.470001  144.570007  145.240005  149.100006  151.369995
#
#       Target-55   Target-54   Target-53   Target-52  ...    Target-9  \
# 0    168.969498  170.000000  166.649994  168.954498  ...  170.762497
# 1    170.000000  166.649994  168.954498  169.972000  ...  174.462006
# 2    166.649994  168.954498  169.972000  168.600494  ...  174.345001
# 3    168.954498  169.972000  168.600494  166.734497  ...  172.697998
# 4    169.972000  168.600494  166.734497  168.100998  ...  175.272003
# ..          ...         ...         ...         ...  ...         ...
# 688  144.570007  145.240005  149.100006  151.369995  ...  175.389999
# 689  145.240005  149.100006  151.369995  153.729996  ...  176.559998
# 690  149.100006  151.369995  153.729996  155.179993  ...  178.750000
# 691  151.369995  153.729996  155.179993  154.619995  ...  174.419998
# 692  153.729996  155.179993  154.619995  153.160004  ...  174.479996
#
#        Target-8    Target-7    Target-6    Target-5    Target-4    Target-3  \
# 0    174.462006  174.345001  172.697998  175.272003  175.190994  172.453995
# 1    174.345001  172.697998  175.272003  175.190994  172.453995  170.072998
# 2    172.697998  175.272003  175.190994  172.453995  170.072998  172.194504
# 3    175.272003  175.190994  172.453995  170.072998  172.194504  172.406998
# 4    175.190994  172.453995  170.072998  172.194504  172.406998  172.007996
# ..          ...         ...         ...         ...         ...         ...
# 688  176.559998  178.750000  174.419998  174.479996  175.899994  178.149994
# 689  178.750000  174.419998  174.479996  175.899994  178.149994  178.149994
# 690  174.419998  174.479996  175.899994  178.149994  178.149994  178.869995
# 691  174.479996  175.899994  178.149994  178.149994  178.869995  179.710007
# 692  175.899994  178.149994  178.149994  178.869995  179.710007  178.300003
#
#        Target-2    Target-1      Target
# 0    170.072998  172.194504  172.406998
# 1    172.194504  172.406998  172.007996
# 2    172.406998  172.007996  171.648499
# 3    172.007996  171.648499  175.548996
# 4    171.648499  175.548996  183.787003
# ..          ...         ...         ...
# 688  178.149994  178.869995  179.710007
# 689  178.869995  179.710007  178.300003
# 690  179.710007  178.300003  179.830002
# 691  178.300003  179.830002  180.380005
# 692  179.830002  180.380005  180.419998
#
# [693 rows x 62 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
print(X)
# Out:
# [[[161.3365]
#   [161.191 ]
#   [163.9695]
#   ...
#   [172.454 ]
#   [170.073 ]
#   [172.1945]]
#
#  [[161.191 ]
#   [163.9695]
#   [164.965 ]
#   ...
#   [170.073 ]
#   [172.1945]
#   [172.407 ]]
#
#  [[163.9695]
#   [164.965 ]
#   [168.61  ]
#   ...
#   [172.1945]
#   [172.407 ]
#   [172.008 ]]
#
#  ...
#
#  [[151.94  ]
#   [149.93  ]
#   [148.47  ]
#   ...
#   [178.87  ]
#   [179.71  ]
#   [178.3   ]]
#
#  [[149.93  ]
#   [148.47  ]
#   [144.57  ]
#   ...
#   [179.71  ]
#   [178.3   ]
#   [179.83  ]]
#
#  [[148.47  ]
#   [144.57  ]
#   [145.24  ]
#   ...
#   [178.3   ]
#   [179.83  ]
#   [180.38  ]]]

# %% [markdown]
# Splitting data into training validation and testing

# %%
q_85 = int(len(dates) * .90)
q_95 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_85+1], X[:q_85+1], y[:q_85+1]

dates_val, X_val, y_val = dates[q_85:q_95+1], X[q_85:q_95+1], y[q_85:q_95+1]
dates_test, X_test, y_test = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])
print(dates_test[0])
print(dates_test[-1])


print(dates[:q_85][-1])
dates[q_85-1:][0]
# Out:
# 2024-02-09 00:00:00
# 2024-04-01 00:00:00
# 2023-12-18 00:00:00
# Timestamp('2023-12-18 00:00:00')

# %% [markdown]
# LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import layers


model = Sequential([layers.Input((window_size_n, 1)),
                    layers.LSTM(512),
                  layers.Dropout(0.001),
                    layers.Dense(512, activation='relu'),
                   # layers.Dropout(0.001),
                   layers.Dense(512, activation='relu'),
                
                    layers.Dense(512, activation='relu'),

                    layers.Dense(1)]
                    )

model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=15)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/15
# 20/20 [==============================] - 10s 407ms/step - loss: 7067.5615 - mean_absolute_error: 69.1018 - val_loss: 3157.7097 - val_mean_absolute_error: 55.7078
# Epoch 2/15
# 20/20 [==============================] - 7s 369ms/step - loss: 787.5698 - mean_absolute_error: 22.9798 - val_loss: 251.2530 - val_mean_absolute_error: 14.7746
# Epoch 3/15
# 20/20 [==============================] - 8s 391ms/step - loss: 67.2883 - mean_absolute_error: 5.8588 - val_loss: 7.8813 - val_mean_absolute_error: 1.9493
# Epoch 4/15
# 20/20 [==============================] - 7s 345ms/step - loss: 14.1447 - mean_absolute_error: 2.7860 - val_loss: 12.8161 - val_mean_absolute_error: 2.6052
# Epoch 5/15
# 20/20 [==============================] - 7s 340ms/step - loss: 13.1480 - mean_absolute_error: 2.7081 - val_loss: 8.6415 - val_mean_absolute_error: 1.9618
# Epoch 6/15
# 20/20 [==============================] - 6s 316ms/step - loss: 12.0642 - mean_absolute_error: 2.5804 - val_loss: 8.6229 - val_mean_absolute_error: 2.1740
# Epoch 7/15
# 20/20 [==============================] - 6s 324ms/step - loss: 15.9402 - mean_absolute_error: 3.0797 - val_loss: 10.2532 - val_mean_absolute_error: 2.1900
# Epoch 8/15
# 20/20 [==============================] - 7s 337ms/step - loss: 19.6616 - mean_absolute_error: 3.4357 - val_loss: 13.0865 - val_mean_absolute_error: 3.0401
# Epoch 9/15
# 20/20 [==============================] - 7s 325ms/step - loss: 13.6069 - mean_absolute_error: 2.7706 - val_loss: 8.1278 - val_mean_absolute_error: 2.0046
# Epoch 10/15
# 20/20 [==============================] - 7s 340ms/step - loss: 14.1833 - mean_absolute_error: 2.9024 - val_loss: 10.7430 - val_mean_absolute_error: 2.2150
# Epoch 11/15
# 20/20 [==============================] - 6s 300ms/step - loss: 13.0529 - mean_absolute_error: 2.6976 - val_loss: 12.5052 - val_mean_absolute_error: 2.9679
# Epoch 12/15
# 20/20 [==============================] - 6s 281ms/step - loss: 13.4866 - mean_absolute_error: 2.8098 - val_loss: 10.7224 - val_mean_absolute_error: 2.6047
# Epoch 13/15
# 20/20 [==============================] - 5s 257ms/step - loss: 14.3759 - mean_absolute_error: 2.9460 - val_loss: 11.1157 - val_mean_absolute_error: 2.2811
# Epoch 14/15
# 20/20 [==============================] - 5s 244ms/step - loss: 11.7872 - mean_absolute_error: 2.5587 - val_loss: 12.3743 - val_mean_absolute_error: 2.4824
# Epoch 15/15
# 20/20 [==============================] - 5s 229ms/step - loss: 13.3038 - mean_absolute_error: 2.7784 - val_loss: 9.3242 - val_mean_absolute_error: 2.0577

# %%
'''
model2 = Sequential([layers.Input((50, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                   layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)
'''
# Out:
# '\nmodel2 = Sequential([layers.Input((50, 1)),\n                    layers.LSTM(64),\n                    layers.Dense(32, activation=\'relu\'),\n                   layers.Dense(32, activation=\'relu\'),\n                    layers.Dense(32, activation=\'relu\'),\n                    layers.Dense(1)])\n\nmodel.compile(loss="mse",\n              optimizer=Adam(learning_rate=0.001),\n              metrics=[\'mean_absolute_error\'])\n\nmodel.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)\n'

# %% [markdown]
# How Model Perform on training data

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 20/20 [==============================] - 2s 73ms/step

# %% [markdown]
# How model performs on validation data

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 2/2 [==============================] - 0s 84ms/step

# %% [markdown]
# How model performs on Testing data

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

a=len(y_test)

s=0
for i in range(a):
  s+=(y_test[i]-test_predictions[i])**2

  print(dates_test[i],"  .|. ",y_test[i],"|",test_predictions[i],(y_test[i]-(y_test[i-1]),test_predictions[i]-test_predictions[i]))
print((s**(1/2))/a)
# Out:
# 2/2 [==============================] - 0s 39ms/step
# 2024-02-09 00:00:00   .|.  174.45 | 169.31898 (-5.970001, 0.0)
# 2024-02-12 00:00:00   .|.  172.34 | 173.62384 (-2.1100006, 0.0)
# 2024-02-13 00:00:00   .|.  168.64 | 171.62148 (-3.699997, 0.0)
# 2024-02-14 00:00:00   .|.  170.98 | 167.86281 (2.3399963, 0.0)
# 2024-02-15 00:00:00   .|.  169.8 | 170.40364 (-1.1799927, 0.0)
# 2024-02-16 00:00:00   .|.  169.51 | 169.43036 (-0.29000854, 0.0)
# 2024-02-20 00:00:00   .|.  167.08 | 168.97722 (-2.4299927, 0.0)
# 2024-02-21 00:00:00   .|.  168.59 | 166.63991 (1.5099945, 0.0)
# 2024-02-22 00:00:00   .|.  174.58 | 168.2082 (5.9900055, 0.0)
# 2024-02-23 00:00:00   .|.  174.99 | 174.04048 (0.41000366, 0.0)
# 2024-02-26 00:00:00   .|.  174.73 | 174.18974 (-0.26000977, 0.0)
# 2024-02-27 00:00:00   .|.  173.54 | 173.70888 (-1.1900024, 0.0)
# 2024-02-28 00:00:00   .|.  173.16 | 172.70125 (-0.37998962, 0.0)
# 2024-02-29 00:00:00   .|.  176.76 | 172.4341 (3.5999908, 0.0)
# 2024-03-01 00:00:00   .|.  178.22 | 175.79451 (1.4600067, 0.0)
# 2024-03-04 00:00:00   .|.  177.58 | 176.99724 (-0.6399994, 0.0)
# 2024-03-05 00:00:00   .|.  174.12 | 176.26718 (-3.4600067, 0.0)
# 2024-03-06 00:00:00   .|.  173.51 | 173.16428 (-0.6100006, 0.0)
# 2024-03-07 00:00:00   .|.  176.82 | 172.76955 (3.3100128, 0.0)
# 2024-03-08 00:00:00   .|.  175.35 | 175.94704 (-1.4700012, 0.0)
# 2024-03-11 00:00:00   .|.  171.96 | 174.51791 (-3.3899994, 0.0)
# 2024-03-12 00:00:00   .|.  175.39 | 171.26117 (3.4299927, 0.0)
# 2024-03-13 00:00:00   .|.  176.56 | 174.64725 (1.1699982, 0.0)
# 2024-03-14 00:00:00   .|.  178.75 | 175.77238 (2.1900024, 0.0)
# 2024-03-15 00:00:00   .|.  174.42 | 177.47887 (-4.330002, 0.0)
# 2024-03-18 00:00:00   .|.  174.48 | 173.52101 (0.05999756, 0.0)
# 2024-03-19 00:00:00   .|.  175.9 | 173.69118 (1.4199982, 0.0)
# 2024-03-20 00:00:00   .|.  178.15 | 175.1939 (2.25, 0.0)
# 2024-03-21 00:00:00   .|.  178.15 | 177.09929 (0.0, 0.0)
# 2024-03-22 00:00:00   .|.  178.87 | 176.96977 (0.7200012, 0.0)
# 2024-03-25 00:00:00   .|.  179.71 | 177.55658 (0.8400116, 0.0)
# 2024-03-26 00:00:00   .|.  178.3 | 178.29268 (-1.4100037, 0.0)
# 2024-03-27 00:00:00   .|.  179.83 | 177.04655 (1.5299988, 0.0)
# 2024-03-28 00:00:00   .|.  180.38 | 178.41537 (0.55000305, 0.0)
# 2024-04-01 00:00:00   .|.  180.42 | 178.8894 (0.039993286, 0.0)
# 0.429642749745622

# %% [markdown]
# Extracting Data to be used by GUI

# %%
row_list=[]
for i in range(len(train_predictions)):
  row_list+=[["AMZN",dates_train[i],train_predictions[i],y_train[i],False]]
for i in range(len(val_predictions)):
  row_list+=[["AMZN",dates_val[i],val_predictions[i],y_val[i],False]]
for i in range(len(test_predictions)):
  row_list+=[["AMZN",dates_test[i],test_predictions[i],y_test[i],True]]

print(row_list[:5])
with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Amazon/AMZN_Stock_ML_CLOSE.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","date","Expected","Actual","isFuture"])
     writer.writerows(row_list)
# Out:
# [['AMZN', Timestamp('2021-06-29 00:00:00'), 171.974, 172.407, False], ['AMZN', Timestamp('2021-06-30 00:00:00'), 172.22012, 172.008, False], ['AMZN', Timestamp('2021-07-01 00:00:00'), 171.68642, 171.6485, False], ['AMZN', Timestamp('2021-07-02 00:00:00'), 171.36324, 175.549, False], ['AMZN', Timestamp('2021-07-06 00:00:00'), 175.025, 183.787, False]]

# %%
'''
from copy import deepcopy
last_window = deepcopy(X_test[-1])
last_date=dates_test[-1]
next_prediction = model.predict(np.array([last_window])).flatten()
next_prediction2= model2.predict(np.array([last_window])).flatten()
next_date=last_date+datetime.timedelta(1)
print(last_date,"|",last_window)
print(next_date ,"|" ,next_prediction, "||||",next_prediction2)

print(["1","2","3","4"][1:])
'''
# Out:
# '\nfrom copy import deepcopy\nlast_window = deepcopy(X_test[-1])\nlast_date=dates_test[-1]\nnext_prediction = model.predict(np.array([last_window])).flatten()\nnext_prediction2= model2.predict(np.array([last_window])).flatten()\nnext_date=last_date+datetime.timedelta(1)\nprint(last_date,"|",last_window)\nprint(next_date ,"|" ,next_prediction, "||||",next_prediction2)\n\nprint(["1","2","3","4"][1:])\n'

# %%
data_dict_close=dict()
for i in data_list_clean:
  data_dict_close[i[0]]=i[4]
print(data_dict_close["2023-11-16"])

print(data_dict_close)
# Out:
# 142.8300018310547
# {'2021-04-01': 158.0500030517578, '2021-04-05': 161.3365020751953, '2021-04-06': 161.1909942626953, '2021-04-07': 163.96949768066406, '2021-04-08': 164.96499633789062, '2021-04-09': 168.61000061035156, '2021-04-12': 168.96949768066406, '2021-04-13': 170.0, '2021-04-14': 166.64999389648438, '2021-04-15': 168.95449829101562, '2021-04-16': 169.9720001220703, '2021-04-19': 168.60049438476562, '2021-04-20': 166.7344970703125, '2021-04-21': 168.1009979248047, '2021-04-22': 165.45199584960938, '2021-04-23': 167.04400634765625, '2021-04-26': 170.4499969482422, '2021-04-27': 170.8715057373047, '2021-04-28': 172.9250030517578, '2021-04-29': 173.5655059814453, '2021-04-30': 173.37100219726562, '2021-05-03': 169.32449340820312, '2021-05-04': 165.593505859375, '2021-05-05': 163.52699279785156, '2021-05-06': 165.31849670410156, '2021-05-07': 164.58050537109375, '2021-05-10

for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_1_year_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict_52_week+=[float(data_dict_close[i])]
week52high=max(dict_52_week)
week52low=min(dict_52_week)


#200 days
dict200day=[]
date_200_day_back= last_future_date-datetime.timedelta(200)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_200_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict200day+=[float(data_dict_close[i])]

#100 days
dict100day=[]
date_100_day_back= last_future_date-datetime.timedelta(100)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_100_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict100day+=[float(data_dict_close[i])]


#50 days
dict50day=[]
date_50_day_back= last_future_date-datetime.timedelta(50)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_50_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict50day+=[float(data_dict_close[i])]


print(dict200day[:5])
avg200day=sum(dict200day)/len(dict200day)
avg100day=sum(dict100day)/len(dict100day)
avg50day=sum(dict50day)/len(dict50day)

row_stock=["AMZN",week52high,week52low,avg200day,avg100day,avg50day]

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Stock_Data_CLOSE.csv', 'a', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])
     writer.writerow(row_stock)
# Out:
# [128.8000030517578, 129.1300048828125, 128.14999389648438, 128.25, 132.2100067138672]

# %% [markdown]
# How Model Is performing?

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# # **WORK IN PROGRESS!!**

# %%
'''
print(next_prediction)
a=np.array(next_prediction)
print(a.shape)
'''
# Out:
# '\nprint(next_prediction)\na=np.array(next_prediction)\nprint(a.shape)\n'

# %%
'''
b=np.append(last_window[1:],next_prediction)
print(last_window.shape)
p=b.reshape(window_size_n,1)
print(p.shape)'''
# Out:
# '\nb=np.append(last_window[1:],next_prediction)\nprint(last_window.shape)\np=b.reshape(window_size_n,1)\nprint(p.shape)'

# %%
'''
nextp= model.predict(np.array([p]))
nextdatep=next_date+datetime.timedelta(1)
d=[]+(nextp)
print(nextdatep,"|",nextp)
for i in range(7):
  p=np.append(p[1:],nextp)
  p=p.reshape(window_size_n,1)

  nextp=model.predict(np.array([p])).flatten()

  nextdatep+=datetime.timedelta(1)
  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:
    nextdatep+=datetime.timedelta(1)
  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])
  d+=(nextp)
print(p)
print(d)
'''
# Out:
# '\nnextp= model.predict(np.array([p]))\nnextdatep=next_date+datetime.timedelta(1)\nd=[]+(nextp)\nprint(nextdatep,"|",nextp)\nfor i in range(7):\n  p=np.append(p[1:],nextp)\n  p=p.reshape(window_size_n,1)\n\n  nextp=model.predict(np.array([p])).flatten()\n\n  nextdatep+=datetime.timedelta(1)\n  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:\n    nextdatep+=datetime.timedelta(1)\n  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])\n  d+=(nextp)\nprint(p)\nprint(d)\n'

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
print(test_predictions[1],dates_test[1])
print(df.loc['2023-09-08'])
# Out:
# 173.62384 2024-02-12 00:00:00
# Close    138.229996
# Name: 2023-09-08 00:00:00, dtype: float64
