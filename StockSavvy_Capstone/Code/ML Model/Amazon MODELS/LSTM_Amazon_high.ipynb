# %% [markdown]
# Getting Data

# %%
import yfinance as yf

# %%
import yfinance as yf
data = yf.download("AMZN", period="48mo")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Data Format

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print(data.shape)
# Out:
# (1007, 6)

# %%
data.to_csv("/Users/shubham/Desktop/compsci_4zp6a_capstone/content/AMZN_demo.csv", sep='\t')

# %% [markdown]
# Data Cleaning

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['High'][0:10]
data['High'][-1:]
# Out:
# Date
# 2024-03-28 00:00:00-04:00    181.699997
# Name: High, dtype: float64

# %%
data.T
# Out:
# Date       2020-03-30 00:00:00-04:00  2020-03-31 00:00:00-04:00  \
# Open                    9.614150e+01               9.821750e+01
# High                    9.868150e+01               9.965100e+01
# Low                     9.561700e+01               9.720050e+01
# Close                   9.819750e+01               9.748600e+01
# Adj Close               9.819750e+01               9.748600e+01
# Volume                  1.225220e+08               1.024720e+08
#
# Date       2020-04-01 00:00:00-04:00  2020-04-02 00:00:00-04:00  \
# Open                    9.664850e+01               9.508200e+01
# High                    9.724800e+01               9.637650e+01
# Low                     9.465000e+01               9.450000e+01
# Close                   9.538500e+01               9.594150e+01
# Adj Close               9.538500e+01               9.594150e+01
# Volume                  8.243800e+07               8.672000e+07
#
# Date       2020-04-03 00:00:00-04:00  2020-04-06 00:00:00-04:00  \
# Open                    9.555750e+01               9.680000e+01
# High                    9.631650e+01               9.992600e+01
# Low                     9.445750e+01               9.650100e+01
# Close                   9.532950e+01               9.987950e+01
# Adj Close               9.532950e+01               9.987950e+01
# Volume                  7.219800e+07               1.154640e+08
#
# Date       2020-04-07 00:00:00-04:00  2020-04-08 00:00:00-04:00  \
# Open                    1.008555e+02               1.010500e+02
# High                    1.017860e+02               1.022000e+02
# Low                     9.988100e+01               1.005575e+02
# Close                   1.005800e+02               1.021500e+02
# Adj Close               1.005800e+02               1.021500e+02
# Volume                  1.022800e+08               7.954600e+07
#
# Date       2020-04-09 00:00:00-04:00  2020-04-13 00:00:00-04:00  ...  \
# Open                    1.022150e+02               1.020000e+02  ...
# High                    1.026500e+02               1.090000e+02  ...
# Low                     1.008830e+02               1.019000e+02  ...
# Close                   1.021380e+02               1.084435e+02  ...
# Adj Close               1.021380e+02               1.084435e+02  ...
# Volume                  9.293000e+07               1.343340e+08  ...
#
# Date       2024-03-15 00:00:00-04:00  2024-03-18 00:00:00-04:00  \
# Open                    1.766400e+02               1.758000e+02
# High                    1.779300e+02               1.766900e+02
# Low                     1.739000e+02               1.742800e+02
# Close                   1.744200e+02               1.744800e+02
# Adj Close               1.744200e+02               1.744800e+02
# Volume                  7.211550e+07               3.125070e+07
#
# Date       2024-03-19 00:00:00-04:00  2024-03-20 00:00:00-04:00  \
# Open                    1.742200e+02               1.761400e+02
# High                    1.760900e+02               1.785300e+02
# Low                     1.735200e+02               1.746400e+02
# Close                   1.759000e+02               1.781500e+02
# Adj Close               1.759000e+02               1.781500e+02
# Volume                  2.688090e+07               2.994720e+07
#
# Date       2024-03-21 00:00:00-04:00  2024-03-22 00:00:00-04:00  \
# Open                    1.799900e+02               1.777500e+02
# High                    1.814200e+02               1.792600e+02
# Low                     1.781500e+02               1.767500e+02
# Close                   1.781500e+02               1.788700e+02
# Adj Close               1.781500e+02               1.788700e+02
# Volume                  3.282430e+07               2.796410e+07
#
# Date       2024-03-25 00:00:00-04:00  2024-03-26 00:00:00-04:00  \
# Open                    1.780100e+02               1.801500e+02
# High                    1.809900e+02               1.804500e+02
# Low                     1.772400e+02               1.779500e+02
# Close                   1.797100e+02               1.783000e+02
# Adj Close               1.797100e+02               1.783000e+02
# Volume                  2.981550e+07               2.965900e+07
#
# Date       2024-03-27 00:00:00-04:00  2024-03-28 00:00:00-04:00
# Open                    1.798800e+02               1.801700e+02
# High                    1.800000e+02               1.817000e+02
# Low                     1.773100e+02               1.792600e+02
# Close                   1.798300e+02               1.803800e+02
# Adj Close               1.798300e+02               1.803800e+02
# Volume                  3.327260e+07               3.805160e+07
#
# [6 rows x 1007 columns]

# %%
import numpy
import pandas as pd
import csv
from datetime import datetime

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/content/AMZN_demo.csv', newline='') as f:
    reader = csv.reader(f)
    data_list = list(reader)
   
data_list_clean=[]
list_clean=[]
k=0
print(str(data_list[0][0]))
for i in data_list[1:]:
  list_clean+=[str(i[0]).split("\t")]
  
for j in list_clean:
    
  date=(j[0][:10])
   
  a=[date]+[float(j[1])]+[float(j[2])]+[float(j[3])]+[float(j[4])]+[float(j[5])]+[float(j[6])]
  data_list_clean+=[a]
   

print(len(data_list))
print(len(data_list_clean))
# Out:
# Date	Open	High	Low	Close	Adj Close	Volume
# 1008
# 1007

# %%
df=pd.DataFrame(data_list_clean[1:],columns=data_list[0][0].split("\t"))
print(df.dtypes)
df_fil=df[['Date','High']]

print(df_fil[:10])
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date        High
# 0  2020-03-31   99.651001
# 1  2020-04-01   97.248001
# 2  2020-04-02   96.376503
# 3  2020-04-03   96.316498
# 4  2020-04-06   99.926003
# 5  2020-04-07  101.786003
# 6  2020-04-08  102.199997
# 7  2020-04-09  102.650002
# 8  2020-04-13  109.000000
# 9  2020-04-14  114.599998

# %%
print(data_list_clean)
# Out:
# [['2020-03-30', 96.1415023803711, 98.68150329589844, 95.61699676513672, 98.19750213623047, 98.19750213623047, 122522000.0], ['2020-03-31', 98.21749877929688, 99.6510009765625, 97.20050048828125, 97.48600006103516, 97.48600006103516, 102472000.0], ['2020-04-01', 96.64849853515625, 97.24800109863281, 94.6500015258789, 95.38500213623047, 95.38500213623047, 82438000.0], ['2020-04-02', 95.08200073242188, 96.37650299072266, 94.5, 95.94149780273438, 95.94149780273438, 86720000.0], ['2020-04-03', 95.55750274658203, 96.31649780273438, 94.4574966430664, 95.32949829101562, 95.32949829101562, 72198000.0], ['2020-04-06', 96.80000305175781, 99.9260025024414, 96.5009994506836, 99.87950134277344, 99.87950134277344, 115464000.0], ['2020-04-07', 100.85549926757812, 101.78600311279297, 99.88099670410156, 100.58000183105469, 100.58000183105469, 102280000.0], ['2020-04-08', 101.05000305175781, 102.19999694824219, 100.55750274658203, 102.1500015258789, 102.1500015258789, 79546000.0], ['2020-04-09', 102.21499633789062, 102.6500015258789, 100.88300323486328, 102.13800048828125, 102.13800048828125, 92930000.0], ['2020-04-13', 102.0, 109.0, 101.9000015258789, 108.44349670410156, 108.44349670410156, 134334000.0], ['2020-04-14', 110.02349853515625, 114.5999984741211, 109.31050109863281, 114.16600036621094, 114.16600036621094, 161744000.0], ['2020-04-15', 112.88400268554688, 116.66850280761719, 112.25, 115.38400268554688, 115.38400268554688, 137332000.0], ['2020-04-16', 117.30000305175781, 123.05000305175781, 116.75, 120.40950012207031, 120.40950012207031, 240764000.0], ['2020-04-17', 118.61650085449219, 120.0, 115.8010025024414, 118.75, 118.75, 158600000.0], ['2020-04-20', 119.49749755859375, 122.2490005493164, 119.30249786376953, 119.68049621582031, 119.68049621582031, 115414000.0], ['2020-04-21', 120.83049774169922, 121.41549682617188, 113.98300170898438, 116.40599822998047, 116.40599822998047, 149534000.0], ['2020-04-22', 118.44999694824219, 119.69999694824219, 117.55000305175781, 118.17449951171875, 118.17449951171875, 84244000.0], ['2020-04-23', 119.9990005493164, 121.21099853515625, 119.10399627685547, 119.97250366210938, 119.97250366210938, 101332000.0], ['2020-04-24', 120.8499984741211, 121.02149963378906, 119.0999984741211, 120.51100158691406, 120.51100158691406, 76498000.0], ['2020-04-27', 122.16000366210938, 122.24400329589844, 118.1500015258789, 118.80000305175781, 118.80000305175781, 112912000.0], ['2020-04-28', 118.6050033569336, 118.67500305175781, 115.30000305175781, 115.7040023803711, 115.7040023803711, 105388000.0], ['2020-04-29', 116.50050354003906, 119.59449768066406, 115.5, 118.635498046875, 118.635498046875, 91832000.0], ['2020-04-30', 120.99199676513672, 123.75, 119.80049896240234, 123.69999694824219, 123.69999694824219, 190692000.0], ['2020-05-01', 116.83999633789062, 118.12200164794922, 112.90950012207031, 114.302001953125, 114.302001953125, 195452000.0], ['2020-05-04', 112.81900024414062, 116.3489990234375, 112.81900024414062, 115.79949951171875, 115.79949951171875, 97318000.0], ['2020-05-05', 117.0, 117.55000305175781, 115.35649871826172, 115.88999938964844, 115.88999938964844, 64850000.0], ['2020-05-06', 116.47200012207031, 117.87249755859375, 116.0, 117.56300354003906, 117.56300354003906, 62356000.0], ['2020-05-07', 118.73899841308594, 118.80000305175781, 117.15550231933594, 118.38050079345703, 118.38050079345703, 67928000.0], ['2020-05-08', 118.60700225830078, 119.36199951171875, 117.8499984741211, 118.98049926757812, 118.98049926757812, 64132000.0], ['2020-05-11', 118.73500061035156, 120.9834976196289, 118.60549926757812, 120.44999694824219, 120.44999694824219, 65184000.0], ['2020-05-12', 120.59249877929688, 120.94999694824219, 117.75, 117.84750366210938, 117.84750366210938, 61498000.0], ['2020-05-13', 118.33999633789062, 120.38500213623047, 116.88999938964844, 118.39600372314453, 118.39600372314453, 95658000.0], ['2020-05-14', 118.05049896240234, 119.56849670410156, 117.6604995727539, 119.44249725341797, 119.44249725341797 ...

# %%
import datetime
def str_to_datetime(s):
  
  split=s.split('-')
  year,month,day=int(split[0]),int(split[1]
  ),int(split[2])
  return datetime.datetime(year=year,month=month,day=day)

df_fil['Date']=df_fil['Date'].apply(str_to_datetime)
# Out:
# /var/folders/dj/2ct0t4413vdb_zyk_9q62gs40000gn/T/ipykernel_25740/1826438051.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Date']=df_fil['Date'].apply(str_to_datetime)

# %%
df_fil['Date']
# Out:
# 0      2020-03-31
# 1      2020-04-01
# 2      2020-04-02
# 3      2020-04-03
# 4      2020-04-06
#           ...
# 1001   2024-03-22
# 1002   2024-03-25
# 1003   2024-03-26
# 1004   2024-03-27
# 1005   2024-03-28
# Name: Date, Length: 1006, dtype: datetime64[ns]

# %%
df_fil.index=df_fil.pop('Date')
print(df_fil)
# Out:
#                   High
# Date
# 2020-03-31   99.651001
# 2020-04-01   97.248001
# 2020-04-02   96.376503
# 2020-04-03   96.316498
# 2020-04-06   99.926003
# ...                ...
# 2024-03-22  179.259995
# 2024-03-25  180.990005
# 2024-03-26  180.449997
# 2024-03-27  180.000000
# 2024-03-28  181.699997
#
# [1006 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df=df_fil
plt.plot(df.index, df['High'])
print(df[:-10])
# Out:
#                   High
# Date
# 2020-03-31   99.651001
# 2020-04-01   97.248001
# 2020-04-02   96.376503
# 2020-04-03   96.316498
# 2020-04-06   99.926003
# ...                ...
# 2024-03-08  178.789993
# 2024-03-11  174.470001
# 2024-03-12  176.759995
# 2024-03-13  177.619995
# 2024-03-14  179.529999
#
# [996 rows x 1 columns]

# %%
str(df_fil.index[-51])[:-9]
# Out:
# '2024-01-17'

# %% [markdown]
# Reshaping data for model

# %%
import numpy as np
window_size_n=30
startdate= str(df_fil.index[window_size_n])[:-9]
lastdate=str(df_fil.index[-1])[:-9]


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['High'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                startdate,
                                lastdate,
                                window_size_n)
windowed_df
# Out:
#     Target Date   Target-30   Target-29   Target-28   Target-27   Target-26  \
# 0    2020-05-13   99.651001   97.248001   96.376503   96.316498   99.926003
# 1    2020-05-14   97.248001   96.376503   96.316498   99.926003  101.786003
# 2    2020-05-15   96.376503   96.316498   99.926003  101.786003  102.199997
# 3    2020-05-18   96.316498   99.926003  101.786003  102.199997  102.650002
# 4    2020-05-19   99.926003  101.786003  102.199997  102.650002  109.000000
# ..          ...         ...         ...         ...         ...         ...
# 971  2024-03-22  171.429993  175.000000  175.389999  170.949997  171.210007
# 972  2024-03-25  175.000000  175.389999  170.949997  171.210007  171.169998
# 973  2024-03-26  175.389999  170.949997  171.210007  171.169998  170.419998
# 974  2024-03-27  170.949997  171.210007  171.169998  170.419998  168.710007
# 975  2024-03-28  171.210007  171.169998  170.419998  168.710007  170.229996
#
#       Target-25   Target-24   Target-23   Target-22  ...    Target-9  \
# 0    101.786003  102.199997  102.650002  109.000000  ...  123.750000
# 1    102.199997  102.650002  109.000000  114.599998  ...  118.122002
# 2    102.650002  109.000000  114.599998  116.668503  ...  116.348999
# 3    109.000000  114.599998  116.668503  123.050003  ...  117.550003
# 4    114.599998  116.668503  123.050003  120.000000  ...  117.872498
# ..          ...         ...         ...         ...  ...         ...
# 971  171.169998  170.419998  168.710007  170.229996  ...  174.470001
# 972  170.419998  168.710007  170.229996  174.800003  ...  176.759995
# 973  168.710007  170.229996  174.800003  175.750000  ...  177.619995
# 974  170.229996  174.800003  175.750000  176.369995  ...  179.529999
# 975  174.800003  175.750000  176.369995  174.619995  ...  177.929993
#
#        Target-8    Target-7    Target-6    Target-5    Target-4    Target-3  \
# 0    118.122002  116.348999  117.550003  117.872498  118.800003  119.362000
# 1    116.348999  117.550003  117.872498  118.800003  119.362000  120.983498
# 2    117.550003  117.872498  118.800003  119.362000  120.983498  120.949997
# 3    117.872498  118.800003  119.362000  120.983498  120.949997  120.385002
# 4    118.800003  119.362000  120.983498  120.949997  120.385002  119.568497
# ..          ...         ...         ...         ...         ...         ...
# 971  176.759995  177.619995  179.529999  177.929993  176.690002  176.089996
# 972  177.619995  179.529999  177.929993  176.690002  176.089996  178.529999
# 973  179.529999  177.929993  176.690002  176.089996  178.529999  181.419998
# 974  177.929993  176.690002  176.089996  178.529999  181.419998  179.259995
# 975  176.690002  176.089996  178.529999  181.419998  179.259995  180.990005
#
#        Target-2    Target-1      Target
# 0    120.983498  120.949997  120.385002
# 1    120.949997  120.385002  119.568497
# 2    120.385002  119.568497  120.550003
# 3    119.568497  120.550003  121.650002
# 4    120.550003  121.650002  124.250000
# ..          ...         ...         ...
# 971  178.529999  181.419998  179.259995
# 972  181.419998  179.259995  180.990005
# 973  179.259995  180.990005  180.449997
# 974  180.990005  180.449997  180.000000
# 975  180.449997  180.000000  181.699997
#
# [976 rows x 32 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
print(X)
# Out:
# [[[ 99.651 ]
#   [ 97.248 ]
#   [ 96.3765]
#   ...
#   [119.362 ]
#   [120.9835]
#   [120.95  ]]
#
#  [[ 97.248 ]
#   [ 96.3765]
#   [ 96.3165]
#   ...
#   [120.9835]
#   [120.95  ]
#   [120.385 ]]
#
#  [[ 96.3765]
#   [ 96.3165]
#   [ 99.926 ]
#   ...
#   [120.95  ]
#   [120.385 ]
#   [119.5685]]
#
#  ...
#
#  [[175.39  ]
#   [170.95  ]
#   [171.21  ]
#   ...
#   [181.42  ]
#   [179.26  ]
#   [180.99  ]]
#
#  [[170.95  ]
#   [171.21  ]
#   [171.17  ]
#   ...
#   [179.26  ]
#   [180.99  ]
#   [180.45  ]]
#
#  [[171.21  ]
#   [171.17  ]
#   [170.42  ]
#   ...
#   [180.99  ]
#   [180.45  ]
#   [180.    ]]]

# %% [markdown]
# Splitting data into training validation and testing

# %%
q_85 = int(len(dates) * .85)
q_95 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_85+1], X[:q_85+1], y[:q_85+1]

dates_val, X_val, y_val = dates[q_85:q_95+1], X[q_85:q_95+1], y[q_85:q_95+1]
dates_test, X_test, y_test = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])
print(dates_test[0])
print(dates_test[-1])


print(dates[:q_85][-1])
dates[q_85-1:][0]
# Out:
# 2024-01-19 00:00:00
# 2024-03-28 00:00:00
# 2023-08-28 00:00:00
# Timestamp('2023-08-28 00:00:00')

# %% [markdown]
# LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import layers


model = Sequential([layers.Input((window_size_n, 1)),
                    layers.LSTM(512),
                  layers.Dropout(0.001),
                    layers.Dense(512, activation='relu'),
                   # layers.Dropout(0.001),
                   layers.Dense(512, activation='relu'),
                
                    layers.Dense(512, activation='relu'),

                    layers.Dense(1)])

model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=15)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/15
# 26/26 [==============================] - 4s 110ms/step - loss: 6540.0747 - mean_absolute_error: 63.4535 - val_loss: 150.0027 - val_mean_absolute_error: 9.7829
# Epoch 2/15
# 26/26 [==============================] - 3s 99ms/step - loss: 437.5430 - mean_absolute_error: 15.6828 - val_loss: 9.4191 - val_mean_absolute_error: 2.4286
# Epoch 3/15
# 26/26 [==============================] - 3s 100ms/step - loss: 11.9876 - mean_absolute_error: 2.6579 - val_loss: 5.4012 - val_mean_absolute_error: 1.7363
# Epoch 4/15
# 26/26 [==============================] - 3s 101ms/step - loss: 9.9925 - mean_absolute_error: 2.3048 - val_loss: 9.7921 - val_mean_absolute_error: 2.5325
# Epoch 5/15
# 26/26 [==============================] - 3s 101ms/step - loss: 11.0808 - mean_absolute_error: 2.4555 - val_loss: 12.5204 - val_mean_absolute_error: 2.9783
# Epoch 6/15
# 26/26 [==============================] - 3s 102ms/step - loss: 11.8191 - mean_absolute_error: 2.6181 - val_loss: 7.1291 - val_mean_absolute_error: 2.0914
# Epoch 7/15
# 26/26 [==============================] - 3s 104ms/step - loss: 12.0095 - mean_absolute_error: 2.6038 - val_loss: 6.3855 - val_mean_absolute_error: 1.9358
# Epoch 8/15
# 26/26 [==============================] - 3s 103ms/step - loss: 10.2282 - mean_absolute_error: 2.3230 - val_loss: 6.3191 - val_mean_absolute_error: 1.9351
# Epoch 9/15
# 26/26 [==============================] - 3s 104ms/step - loss: 10.5272 - mean_absolute_error: 2.3767 - val_loss: 5.8573 - val_mean_absolute_error: 1.8170
# Epoch 10/15
# 26/26 [==============================] - 3s 104ms/step - loss: 9.6466 - mean_absolute_error: 2.3172 - val_loss: 11.9551 - val_mean_absolute_error: 2.9192
# Epoch 11/15
# 26/26 [==============================] - 3s 104ms/step - loss: 12.4587 - mean_absolute_error: 2.7000 - val_loss: 5.1241 - val_mean_absolute_error: 1.6686
# Epoch 12/15
# 26/26 [==============================] - 3s 106ms/step - loss: 10.1135 - mean_absolute_error: 2.3783 - val_loss: 5.5089 - val_mean_absolute_error: 1.7600
# Epoch 13/15
# 26/26 [==============================] - 3s 104ms/step - loss: 9.5421 - mean_absolute_error: 2.2462 - val_loss: 5.3693 - val_mean_absolute_error: 1.7444
# Epoch 14/15
# 26/26 [==============================] - 3s 108ms/step - loss: 10.7597 - mean_absolute_error: 2.4669 - val_loss: 6.9054 - val_mean_absolute_error: 2.0499
# Epoch 15/15
# 26/26 [==============================] - 3s 105ms/step - loss: 9.0638 - mean_absolute_error: 2.1822 - val_loss: 5.3463 - val_mean_absolute_error: 1.7372

# %% [markdown]
# How Model Perform on training data

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 26/26 [==============================] - 1s 38ms/step

# %% [markdown]
# How model performs on validation data

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 36ms/step

# %% [markdown]
# How model performs on Testing data

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

a=len(y_test)

s=0
for i in range(a):
  s+=(y_test[i]-test_predictions[i])**2

  print(dates_test[i],"  .|. ",y_test[i],"|",test_predictions[i],(y_test[i]-(y_test[i-1]),test_predictions[i]-test_predictions[i-1]))
print((s**(1/2))/a)
# Out:
# 2/2 [==============================] - 0s 31ms/step
# 2024-01-19 00:00:00   .|.  155.76 | 153.81564 (-25.940002, -24.322998)
# 2024-01-22 00:00:00   .|.  157.05 | 155.82625 (1.2900085, 2.0106049)
# 2024-01-23 00:00:00   .|.  156.21 | 156.80605 (-0.83999634, 0.97979736)
# 2024-01-24 00:00:00   .|.  158.51 | 155.5819 (2.2999878, -1.2241516)
# 2024-01-25 00:00:00   .|.  158.51 | 158.44876 (0.0, 2.866867)
# 2024-01-26 00:00:00   .|.  160.72 | 158.05856 (2.2100067, -0.39019775)
# 2024-01-29 00:00:00   .|.  161.29 | 160.50772 (0.56999207, 2.4491577)
# 2024-01-30 00:00:00   .|.  161.73 | 160.82399 (0.44000244, 0.31626892)
# 2024-01-31 00:00:00   .|.  159.01 | 161.15204 (-2.7200012, 0.3280487)
# 2024-02-01 00:00:00   .|.  159.76 | 158.00392 (0.75, -3.148117)
# 2024-02-02 00:00:00   .|.  172.5 | 159.38776 (12.7400055, 1.3838348)
# 2024-02-05 00:00:00   .|.  170.55 | 173.26898 (-1.949997, 13.881226)
# 2024-02-06 00:00:00   .|.  170.71 | 169.09708 (0.16000366, -4.1719055)
# 2024-02-07 00:00:00   .|.  170.88 | 169.24284 (0.16999817, 0.14576721)
# 2024-02-08 00:00:00   .|.  171.43 | 169.78163 (0.5499878, 0.53878784)
# 2024-02-09 00:00:00   .|.  175.0 | 170.2759 (3.5700073, 0.4942627)
# 2024-02-12 00:00:00   .|.  175.39 | 173.937 (0.3899994, 3.6611023)
# 2024-02-13 00:00:00   .|.  170.95 | 173.82861 (-4.4400024, -0.10838318)
# 2024-02-14 00:00:00   .|.  171.21 | 169.01367 (0.26000977, -4.8149414)
# 2024-02-15 00:00:00   .|.  171.17 | 170.05795 (-0.040008545, 1.044281)
# 2024-02-16 00:00:00   .|.  170.42 | 170.13489 (-0.75, 0.076934814)
# 2024-02-20 00:00:00   .|.  168.71 | 169.24194 (-1.7099915, -0.89294434)
# 2024-02-21 00:00:00   .|.  170.23 | 167.54456 (1.519989, -1.6973877)
# 2024-02-22 00:00:00   .|.  174.8 | 169.50404 (4.5700073, 1.9594879)
# 2024-02-23 00:00:00   .|.  175.75 | 174.11205 (0.94999695, 4.6080017)
# 2024-02-26 00:00:00   .|.  176.37 | 174.35059 (0.6199951, 0.23854065)
# 2024-02-27 00:00:00   .|.  174.62 | 174.78055 (-1.75, 0.42996216)
# 2024-02-28 00:00:00   .|.  174.05 | 172.98145 (-0.56999207, -1.7991028)
# 2024-02-29 00:00:00   .|.  177.22 | 172.66003 (3.1699982, -0.32141113)
# 2024-03-01 00:00:00   .|.  178.73 | 176.06503 (1.5099945, 3.4049988)
# 2024-03-04 00:00:00   .|.  180.14 | 177.13483 (1.4100037, 1.0697937)
# 2024-03-05 00:00:00   .|.  176.93 | 178.25772 (-3.2100067, 1.1228943)
# 2024-03-06 00:00:00   .|.  176.46 | 174.91144 (-0.46998596, -3.346283)
# 2024-03-07 00:00:00   .|.  177.99 | 174.89325 (1.5299988, -0.018188477)
# 2024-03-08 00:00:00   .|.  178.79 | 176.62433 (0.7999878, 1.7310791)
# 2024-03-11 00:00:00   .|.  174.47 | 177.17917 (-4.319992, 0.5548401)
# 2024-03-12 00:00:00   .|.  176.76 | 172.64114 (2.2899933, -4.538025)
# 2024-03-13 00:00:00   .|.  177.62 | 175.63757 (0.8600006, 2.9964294)
# 2024-03-14 00:00:00   .|.  179.53 | 176.33331 (1.9100037, 0.69573975)
# 2024-03-15 00:00:00   .|.  177.93 | 177.9833 (-1.6000061, 1.6499939)
# 2024-03-18 00:00:00   .|.  176.69 | 176.17682 (-1.2399902, -1.806488)
# 2024-03-19 00:00:00   .|.  176.09 | 175.1236 (-0.6000061, -1.0532227)
# 2024-03-20 00:00:00   .|.  178.53 | 174.76416 (2.4400024, -0.35943604)
# 2024-03-21 00:00:00   .|.  181.42 | 177.30502 (2.8899994, 2.540863)
# 2024-03-22 00:00:00   .|.  179.26 | 179.7932 (-2.1600037, 2.4881744)
# 2024-03-25 00:00:00   .|.  180.99 | 177.24875 (1.730011, -2.5444489)
# 2024-03-26 00:00:00   .|.  180.45 | 179.22003 (-0.54000854, 1.971283)
# 2024-03-27 00:00:00   .|.  180.0 | 178.57222 (-0.44999695, -0.6478119)
# 2024-03-28 00:00:00   .|.  181.7 | 178.13864 (1.699997, -0.4335785)
# 0.4361334333750709

# %% [markdown]
# Extracting Data to be used by GUI

# %%
row_list=[]
for i in range(len(train_predictions)):
  row_list+=[["AMZN",dates_train[i],train_predictions[i],y_train[i],False]]
for i in range(len(val_predictions)):
  row_list+=[["AMZN",dates_val[i],val_predictions[i],y_val[i],False]]
for i in range(len(test_predictions)):
  row_list+=[["AMZN",dates_test[i],test_predictions[i],y_test[i],True]]

print(row_list[:5])
with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Amazon/AMZN_Stock_ML_High.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","date","Expected","Actual","isFuture"])
     writer.writerows(row_list)
# Out:
# [['AMZN', Timestamp('2020-05-13 00:00:00'), 120.558846, 120.385, False], ['AMZN', Timestamp('2020-05-14 00:00:00'), 119.949524, 119.5685, False], ['AMZN', Timestamp('2020-05-15 00:00:00'), 119.169106, 120.55, False], ['AMZN', Timestamp('2020-05-18 00:00:00'), 120.584915, 121.65, False], ['AMZN', Timestamp('2020-05-19 00:00:00'), 121.62409, 124.25, False]]

# %%
'''
from copy import deepcopy
last_window = deepcopy(X_test[-1])
last_date=dates_test[-1]
next_prediction = model.predict(np.array([last_window])).flatten()
next_prediction2= model2.predict(np.array([last_window])).flatten()
next_date=last_date+datetime.timedelta(1)
print(last_date,"|",last_window)
print(next_date ,"|" ,next_prediction, "||||",next_prediction2)

print(["1","2","3","4"][1:])
'''
# Out:
# '\nfrom copy import deepcopy\nlast_window = deepcopy(X_test[-1])\nlast_date=dates_test[-1]\nnext_prediction = model.predict(np.array([last_window])).flatten()\nnext_prediction2= model2.predict(np.array([last_window])).flatten()\nnext_date=last_date+datetime.timedelta(1)\nprint(last_date,"|",last_window)\nprint(next_date ,"|" ,next_prediction, "||||",next_prediction2)\n\nprint(["1","2","3","4"][1:])\n'

# %%
data_dict_close=dict()
for i in data_list_clean:
  data_dict_close[i[0]]=i[4]
print(data_dict_close["2023-11-16"])

print(data_dict_close)
# Out:
# 142.8300018310547
# {'2020-03-30': 98.19750213623047, '2020-03-31': 97.48600006103516, '2020-04-01': 95.38500213623047, '2020-04-02': 95.94149780273438, '2020-04-03': 95.32949829101562, '2020-04-06': 99.87950134277344, '2020-04-07': 100.58000183105469, '2020-04-08': 102.1500015258789, '2020-04-09': 102.13800048828125, '2020-04-13': 108.44349670410156, '2020-04-14': 114.16600036621094, '2020-04-15': 115.38400268554688, '2020-04-16': 120.40950012207031, '2020-04-17': 118.75, '2020-04-20': 119.68049621582031, '2020-04-21': 116.40599822998047, '2020-04-22': 118.17449951171875, '2020-04-23': 119.97250366210938, '2020-04-24': 120.51100158691406, '2020-04-27': 118.80000305175781, '2020-04-28': 115.7040023803711, '2020-04-29': 118.635498046875, '2020-04-30': 123.69999694824219, '2020-05-01': 114.302001953125, '2020-05-04': 115.79949951171875, '2020-05-05': 115.88999938964844, '2020-05-06': 117.56300354003906, '2020-05-07': 118.38050079345703, '2020-05-08': 118.98049926757812, '2020-05-11': 120.44999694824219, '2020-05-12': 117.84750366210938, '2020-05-13': 118.39600372314453, '2020-05-14': 119.44249725341797, '2020-05-15': 120.48899841308594, '2020-05-18': 121.31300354003906, '2020-05-19': 122.46649932861328, '2020-05-20': 124.89700317382812, '2020-05-21': 122.33699798583984, '2020-05-22': 121.84400177001953, '2020-05-26': 121.09300231933594, '2020-05-27': 120.51950073242188, '2020-05-28': 120.05500030517578, '2020-05-29': 122.11849975585938, '2020-06-01': 123.552001953125, '2020-06-02': 123.62049865722656, '2020-06-03': 123.91999816894531, '2020-06-04': 123.02999877929688, '2020-06-05': 124.1500015258789, '2020-06-08': 126.2030029296875, '2020-06-09': 130.04299926757812, '2020-06-10': 132.37249755859375, '2020-06-11': 127.89800262451172, '2020-06-12': 127.2509994506836, '2020-06-15': 128.63400268554688, '2020-06-16': 130.7635040283203, '2020-06-17': 132.0489959716797, '2020-06-18': 132.69900512695312, '2020-06-19': 133.75050354003906, '2020-06-22': 135.6909942626953, '2020-06-23': 138.2205047607422, '2020-06-24': 136.72000122070312, '2020-06-25': 137.72900390625, '2020-06-26': 134.64349365234375, '2020-06-29': 134.0189971923828, '2020-06-30': 137.9409942626953, '2020-07-01': 143.93499755859375, '2020-07-02': 144.51499938964844, '2020-07-06': 152.8520050048828, '2020-07-07': 150.00599670410156, '2020-07-08': 154.0554962158203, '2020-07-09': 159.13150024414062, '2020-07-10': 160.0, '2020-07-13': 155.1999969482422, '2020-07-14': 154.1999969482422, '2020-07-15': 150.44349670410156, '2020-07-16': 149.9949951171875, '2020-07-17': 148.09849548339844, '2020-07-20': 159.8419952392578, '2020-07-21': 156.9145050048828, '2020-07-22': 154.99549865722656, '2020-07-23': 149.32749938964844, '2020-07-24': 150.44549560546875, '2020-07-27': 152.760498046875, '2020-07-28': 150.01649475097656, '2020-07-29': 151.67649841308594, '2020-07-30': 152.593994140625, '2020-07-31': 158.23399353027344, '2020-08-03': 155.59449768066406, '2020-08-04': 156.94149780273438, '2020-08-05': 160.25149536132812, '2020-08-06': 161.25, '2020-08-07': 158.3730010986328, '2020-08-10': 157.4080047607422, '2020-08-11': 154.0334930419922, '2020-08-12': 158.11199951171875, '2020-08-13': 158.05099487304688, '2020-08-14': 157.4010009765625, '2020-08-17': 159.12049865722656, '2020-08-18': 165.62449645996094, '2020-08-19': 163.0240020751953, '2020-08-20': 164.86849975585938, '2020-08-21': 164.23599243164062, '2020-08-24': 165.3730010986328, '2020-08-25': 167.32449340820312, '2020-08-26': 172.09249877929688, '2020-08-27': 170.0, '2020-08-28': 170.08999633789062, '2020-08-31': 172.54800415039062, '2020-09-01': 174.95599365234375, '2020-09-02': 176.57249450683594, '2020-09-03': 168.39999389648438, '2020-09-04': 164.7310028076172, '2020-09-08': 157.49200439453125, '2020-09-09': 163.4304962158203, '2020-09-10': 158.7554931640625, '2020-09-11': 155.81100463867188, '2020-09-14': 155.14849853515625, '2020-09-15': 157.80650329589844, '2020-09-16': 153.90499877929688, '2020-09-17': 150.43649291992188, '2020-09-18': 1 ...

# %% [markdown]
# Calculating Statistical values and Extracting to File for GUI

# %%
'''
dict_52_week=[]
from dateutil.relativedelta import relativedelta
last_future_date=dates_val[-1]
date_1_year_back= last_future_date-relativedelta(years=1)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_1_year_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict_52_week+=[float(data_dict_close[i])]
week52high=max(dict_52_week)
week52low=min(dict_52_week)


#200 days
dict200day=[]
date_200_day_back= last_future_date-datetime.timedelta(200)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_200_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict200day+=[float(data_dict_close[i])]

#100 days
dict100day=[]
date_100_day_back= last_future_date-datetime.timedelta(100)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_100_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict100day+=[float(data_dict_close[i])]


#50 days
dict50day=[]
date_50_day_back= last_future_date-datetime.timedelta(50)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_50_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict50day+=[float(data_dict_close[i])]


print(dict200day[:5])
avg200day=sum(dict200day)/len(dict200day)
avg100day=sum(dict100day)/len(dict100day)
avg50day=sum(dict50day)/len(dict50day)

row_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]

with open('Stock_Data_HIGH.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])
     writer.writerow(row_stock)
     '''
# Out:
# '\ndict_52_week=[]\nfrom dateutil.relativedelta import relativedelta\nlast_future_date=dates_val[-1]\ndate_1_year_back= last_future_date-relativedelta(years=1)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_1_year_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict_52_week+=[float(data_dict_close[i])]\nweek52high=max(dict_52_week)\nweek52low=min(dict_52_week)\n\n\n#200 days\ndict200day=[]\ndate_200_day_back= last_future_date-datetime.timedelta(200)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_200_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict200day+=[float(data_dict_close[i])]\n\n#100 days\ndict100day=[]\ndate_100_day_back= last_future_date-datetime.timedelta(100)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_100_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict100day+=[float(data_dict_close[i])]\n\n\n#50 days\ndict50day=[]\ndate_50_day_back= last_future_date-datetime.timedelta(50)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_50_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict50day+=[float(data_dict_close[i])]\n\n\nprint(dict200day[:5])\navg200day=sum(dict200day)/len(dict200day)\navg100day=sum(dict100day)/len(dict100day)\navg50day=sum(dict50day)/len(dict50day)\n\nrow_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]\n\nwith open(\'Stock_Data_HIGH.csv\', \'w\', newline=\'\') as file:\n     writer = csv.writer(file)\n     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])\n     writer.writerow(row_stock)\n     '

# %% [markdown]
# How Model Is performing?

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# # **WORK IN PROGRESS!!**

# %%
'''
print(next_prediction)
a=np.array(next_prediction)
print(a.shape)
'''
# Out:
# '\nprint(next_prediction)\na=np.array(next_prediction)\nprint(a.shape)\n'

# %%
'''
b=np.append(last_window[1:],next_prediction)
print(last_window.shape)
p=b.reshape(window_size_n,1)
print(p.shape)
'''
# Out:
# '\nb=np.append(last_window[1:],next_prediction)\nprint(last_window.shape)\np=b.reshape(window_size_n,1)\nprint(p.shape)\n'

# %%
'''
nextp= model.predict(np.array([p]))
nextdatep=next_date+datetime.timedelta(1)
d=[]+(nextp)
print(nextdatep,"|",nextp)
for i in range(7):
  p=np.append(p[1:],nextp)
  p=p.reshape(window_size_n,1)

  nextp=model.predict(np.array([p])).flatten()

  nextdatep+=datetime.timedelta(1)
  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:
    nextdatep+=datetime.timedelta(1)
  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])
  d+=(nextp)
print(p)
print(d)
'''
# Out:
# '\nnextp= model.predict(np.array([p]))\nnextdatep=next_date+datetime.timedelta(1)\nd=[]+(nextp)\nprint(nextdatep,"|",nextp)\nfor i in range(7):\n  p=np.append(p[1:],nextp)\n  p=p.reshape(window_size_n,1)\n\n  nextp=model.predict(np.array([p])).flatten()\n\n  nextdatep+=datetime.timedelta(1)\n  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:\n    nextdatep+=datetime.timedelta(1)\n  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])\n  d+=(nextp)\nprint(p)\nprint(d)\n'

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
print(test_predictions[1],dates_test[1])
print(df.loc['2023-09-08'])
# Out:
# 155.82625 2024-01-22 00:00:00
# High    138.850006
# Name: 2023-09-08 00:00:00, dtype: float64
