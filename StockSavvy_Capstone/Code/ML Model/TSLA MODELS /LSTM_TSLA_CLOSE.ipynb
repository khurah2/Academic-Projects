# %% [markdown]
# Getting Data

# %%
import yfinance as yf

# %%
import yfinance as yf
data = yf.download("TSLA", period="48mo")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Data Format

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print(data.shape)
# Out:
# (1006, 6)

# %%
data.to_csv("/Users/shubham/Desktop/compsci_4zp6a_capstone/content/TSLA_demo.csv", sep='\t')

# %% [markdown]
# Data Cleaning

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['Close'][0:10]
data['Close'][-1:]
# Out:
# Date
# 2024-04-01 00:00:00-04:00    171.237595
# Name: Close, dtype: float64

# %%
data.T
# Out:
# Date       2020-04-01 00:00:00-04:00  2020-04-02 00:00:00-04:00  \
# Open                    3.360000e+01               3.206867e+01
# High                    3.426333e+01               3.295067e+01
# Low                     3.167333e+01               2.976000e+01
# Close                   3.210400e+01               3.029800e+01
# Adj Close               3.210400e+01               3.029800e+01
# Volume                  2.002980e+08               2.978760e+08
#
# Date       2020-04-03 00:00:00-04:00  2020-04-06 00:00:00-04:00  \
# Open                    3.396667e+01               3.408000e+01
# High                    3.436600e+01               3.473333e+01
# Low                     3.122600e+01               3.319733e+01
# Close                   3.200067e+01               3.441600e+01
# Adj Close               3.200067e+01               3.441600e+01
# Volume                  3.384315e+08               2.235270e+08
#
# Date       2020-04-07 00:00:00-04:00  2020-04-08 00:00:00-04:00  \
# Open                    3.633333e+01               3.694667e+01
# High                    3.766667e+01               3.714733e+01
# Low                     3.548933e+01               3.555533e+01
# Close                   3.636333e+01               3.658933e+01
# Adj Close               3.636333e+01               3.658933e+01
# Volume                  2.687970e+08               1.898400e+08
#
# Date       2020-04-09 00:00:00-04:00  2020-04-13 00:00:00-04:00  \
# Open                    3.747267e+01               3.934400e+01
# High                    3.834533e+01               4.346667e+01
# Low                     3.714067e+01               3.870200e+01
# Close                   3.820000e+01               4.339667e+01
# Adj Close               3.820000e+01               4.339667e+01
# Volume                  2.047500e+08               3.371310e+08
#
# Date       2020-04-14 00:00:00-04:00  2020-04-15 00:00:00-04:00  ...  \
# Open                    4.659800e+01               4.946667e+01  ...
# High                    4.945867e+01               5.020867e+01  ...
# Low                     4.616200e+01               4.733333e+01  ...
# Close                   4.732600e+01               4.865533e+01  ...
# Adj Close               4.732600e+01               4.865533e+01  ...
# Volume                  4.586475e+08               3.536550e+08  ...
#
# Date       2024-03-18 00:00:00-04:00  2024-03-19 00:00:00-04:00  \
# Open                    1.700200e+02               1.723600e+02
# High                    1.747200e+02               1.728200e+02
# Low                     1.659000e+02               1.674200e+02
# Close                   1.738000e+02               1.713200e+02
# Adj Close               1.738000e+02               1.713200e+02
# Volume                  1.082144e+08               7.727140e+07
#
# Date       2024-03-20 00:00:00-04:00  2024-03-21 00:00:00-04:00  \
# Open                    1.730000e+02               1.763900e+02
# High                    1.762500e+02               1.781800e+02
# Low                     1.708200e+02               1.718000e+02
# Close                   1.756600e+02               1.728200e+02
# Adj Close               1.756600e+02               1.728200e+02
# Volume                  8.384670e+07               7.317800e+07
#
# Date       2024-03-22 00:00:00-04:00  2024-03-25 00:00:00-04:00  \
# Open                    1.666900e+02               1.687600e+02
# High                    1.712000e+02               1.752400e+02
# Low                     1.663000e+02               1.687300e+02
# Close                   1.708300e+02               1.726300e+02
# Adj Close               1.708300e+02               1.726300e+02
# Volume                  7.545470e+07               7.422860e+07
#
# Date       2024-03-26 00:00:00-04:00  2024-03-27 00:00:00-04:00  \
# Open                    1.785800e+02               1.814100e+02
# High                    1.842500e+02               1.819100e+02
# Low                     1.773800e+02               1.760000e+02
# Close                   1.776700e+02               1.798300e+02
# Adj Close               1.776700e+02               1.798300e+02
# Volume                  1.131862e+08               8.180400e+07
#
# Date       2024-03-28 00:00:00-04:00  2024-04-01 00:00:00-04:00
# Open                    1.774500e+02               1.761600e+02
# High                    1.795700e+02               1.767500e+02
# Low                     1.753000e+02               1.702100e+02
# Close                   1.757900e+02               1.712376e+02
# Adj Close               1.757900e+02               1.712376e+02
# Volume                  7.765480e+07               4.424627e+07
#
# [6 rows x 1006 columns]

# %%
import numpy
import pandas as pd
import csv
from datetime import datetime

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/content/TSLA_demo.csv', newline='') as f:
    reader = csv.reader(f)
    data_list = list(reader)
   
data_list_clean=[]
list_clean=[]
k=0
print(str(data_list[0][0]))
for i in data_list[1:]:
  list_clean+=[str(i[0]).split("\t")]
  
for j in list_clean:
    
  date=(j[0][:10])
   
  a=[date]+[float(j[1])]+[float(j[2])]+[float(j[3])]+[float(j[4])]+[float(j[5])]+[float(j[6])]
  data_list_clean+=[a]
   

print(len(data_list))
print(len(data_list_clean))
# Out:
# Date	Open	High	Low	Close	Adj Close	Volume
# 1007
# 1006

# %%
df=pd.DataFrame(data_list_clean[1:],columns=data_list[0][0].split("\t"))
print(df.dtypes)
df_fil=df[['Date','Close']]

print(df_fil[:10])
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date      Close
# 0  2020-04-02  30.298000
# 1  2020-04-03  32.000668
# 2  2020-04-06  34.416000
# 3  2020-04-07  36.363335
# 4  2020-04-08  36.589333
# 5  2020-04-09  38.200001
# 6  2020-04-13  43.396667
# 7  2020-04-14  47.326000
# 8  2020-04-15  48.655334
# 9  2020-04-16  49.680668

# %%
print(data_list_clean)
# Out:
# [['2020-04-01', 33.599998474121094, 34.26333236694336, 31.67333221435547, 32.104000091552734, 32.104000091552734, 200298000.0], ['2020-04-02', 32.068668365478516, 32.95066833496094, 29.760000228881836, 30.29800033569336, 30.29800033569336, 297876000.0], ['2020-04-03', 33.96666717529297, 34.36600112915039, 31.22599983215332, 32.000667572021484, 32.000667572021484, 338431500.0], ['2020-04-06', 34.08000183105469, 34.733333587646484, 33.19733428955078, 34.41600036621094, 34.41600036621094, 223527000.0], ['2020-04-07', 36.33333206176758, 37.66666793823242, 35.48933410644531, 36.36333465576172, 36.36333465576172, 268797000.0], ['2020-04-08', 36.9466667175293, 37.14733123779297, 35.55533218383789, 36.589332580566406, 36.589332580566406, 189840000.0], ['2020-04-09', 37.4726676940918, 38.345333099365234, 37.14066696166992, 38.20000076293945, 38.20000076293945, 204750000.0], ['2020-04-13', 39.34400177001953, 43.46666717529297, 38.70199966430664, 43.39666748046875, 43.39666748046875, 337131000.0], ['2020-04-14', 46.597999572753906, 49.45866775512695, 46.1619987487793, 47.32600021362305, 47.32600021362305, 458647500.0], ['2020-04-15', 49.46666717
py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Date']=df_fil['Date'].apply(str_to_datetime)

# %%
df_fil['Date']
# Out:
# 0      2020-04-02
# 1      2020-04-03
# 2      2020-04-06
# 3      2020-04-07
# 4      2020-04-08
#           ...
# 1000   2024-03-25
# 1001   2024-03-26
# 1002   2024-03-27
# 1003   2024-03-28
# 1004   2024-04-01
# Name: Date, Length: 1005, dtype: datetime64[ns]

# %%
df_fil.index=df_fil.pop('Date')
print(df_fil)
# Out:
#                  Close
# Date
# 2020-04-02   30.298000
# 2020-04-03   32.000668
# 2020-04-06   34.416000
# 2020-04-07   36.363335
# 2020-04-08   36.589333
# ...                ...
# 2024-03-25  172.630005
# 2024-03-26  177.669998
# 2024-03-27  179.830002
# 2024-03-28  175.789993
# 2024-04-01  171.237595
#
# [1005 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df=df_fil
plt.plot(df.index, df['Close'])
print(df[:-10])
# Out:
#                  Close
# Date
# 2020-04-02   30.298000
# 2020-04-03   32.000668
# 2020-04-06   34.416000
# 2020-04-07   36.363335
# 2020-04-08   36.589333
# ...                ...
# 2024-03-11  177.770004
# 2024-03-12  177.539993
# 2024-03-13  169.479996
# 2024-03-14  162.500000
# 2024-03-15  163.570007
#
# [995 rows x 1 columns]

# %%
str(df_fil.index[-51])[:-9]
# Out:
# '2024-01-18'

# %% [markdown]
# Reshaping data for model

# %%
import numpy as np
window_size_n=30
startdate= str(df_fil.index[window_size_n])[:-9]
lastdate=str(df_fil.index[-1])[:-9]


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                startdate,
                                lastdate,
                                window_size_n)
windowed_df
# Out:
#     Target Date   Target-30   Target-29   Target-28   Target-27   Target-26  \
# 0    2020-05-15   30.298000   32.000668   34.416000   36.363335   36.589333
# 1    2020-05-18   32.000668   34.416000   36.363335   36.589333   38.200001
# 2    2020-05-19   34.416000   36.363335   36.589333   38.200001   43.396667
# 3    2020-05-20   36.363335   36.589333   38.200001   43.396667   47.326000
# 4    2020-05-21   36.589333   38.200001   43.396667   47.326000   48.655334
# ..          ...         ...         ...         ...         ...         ...
# 970  2024-03-25  193.570007  188.130005  184.020004  188.710007  200.449997
# 971  2024-03-26  188.130005  184.020004  188.710007  200.449997  199.949997
# 972  2024-03-27  184.020004  188.710007  200.449997  199.949997  193.759995
# 973  2024-03-28  188.710007  200.449997  199.949997  193.759995  194.770004
# 974  2024-04-01  200.449997  199.949997  193.759995  194.770004  197.410004
#
#       Target-25   Target-24   Target-23   Target-22  ...    Target-9  \
# 0     38.200001   43.396667   47.326000   48.655334  ...   50.745998
# 1     43.396667   47.326000   48.655334   49.680668  ...   51.214001
# 2     47.326000   48.655334   49.680668   50.259335  ...   52.172001
# 3     48.655334   49.680668   50.259335   49.757332  ...   52.002666
# 4     49.680668   50.259335   49.757332   45.781334  ...   54.627998
# ..          ...         ...         ...         ...  ...         ...
# 970  199.949997  193.759995  194.770004  197.410004  ...  177.539993
# 971  193.759995  194.770004  197.410004  191.970001  ...  169.479996
# 972  194.770004  197.410004  191.970001  199.399994  ...  162.500000
# 973  197.410004  191.970001  199.399994  199.729996  ...  163.570007
# 974  191.970001  199.399994  199.729996  202.039993  ...  173.800003
#
#        Target-8    Target-7    Target-6    Target-5    Target-4    Target-3  \
# 0     51.214001   52.172001   52.002666   54.627998   54.085999   53.960667
# 1     52.172001   52.002666   54.627998   54.085999   53.960667   52.730667
# 2     52.002666   54.627998   54.085999   53.960667   52.730667   53.555332
# 3     54.627998   54.085999   53.960667   52.730667   53.555332   53.278000
# 4     54.085999   53.960667   52.730667   53.555332   53.278000   54.242001
# ..          ...         ...         ...         ...         ...         ...
# 970  169.479996  162.500000  163.570007  173.800003  171.320007  175.660004
# 971  162.500000  163.570007  173.800003  171.320007  175.660004  172.820007
# 972  163.570007  173.800003  171.320007  175.660004  172.820007  170.830002
# 973  173.800003  171.320007  175.660004  172.820007  170.830002  172.630005
# 974  171.320007  175.660004  172.820007  170.830002  172.630005  177.669998
#
#        Target-2    Target-1      Target
# 0     52.730667   53.555332   53.278000
# 1     53.555332   53.278000   54.242001
# 2     53.278000   54.242001   53.867332
# 3     54.242001   53.867332   54.370667
# 4     53.867332   54.370667   55.173332
# ..          ...         ...         ...
# 970  172.820007  170.830002  172.630005
# 971  170.830002  172.630005  177.669998
# 972  172.630005  177.669998  179.830002
# 973  177.669998  179.830002  175.789993
# 974  179.830002  175.789993  171.237595
#
# [975 rows x 32 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
print(X)
# Out:
# [[[ 30.298   ]
#   [ 32.000668]
#   [ 34.416   ]
#   ...
#   [ 53.960667]
#   [ 52.730667]
#   [ 53.555332]]
#
#  [[ 32.000668]
#   [ 34.416   ]
#   [ 36.363335]
#   ...
#   [ 52.730667]
#   [ 53.555332]
#   [ 53.278   ]]
#
#  [[ 34.416   ]
#   [ 36.363335]
#   [ 36.589333]
#   ...
#   [ 53.555332]
#   [ 53.278   ]
#   [ 54.242   ]]
#
#  ...
#
#  [[184.02    ]
#   [188.71    ]
#   [200.45    ]
#   ...
#   [170.83    ]
#   [172.63    ]
#   [177.67    ]]
#
#  [[188.71    ]
#   [200.45    ]
#   [199.95    ]
#   ...
#   [172.63    ]
#   [177.67    ]
#   [179.83    ]]
#
#  [[200.45    ]
#   [199.95    ]
#   [193.76    ]
#   ...
#   [177.67    ]
#   [179.83    ]
#   [175.79    ]]]

# %% [markdown]
# Splitting data into training validation and testing

# %%
q_85 = int(len(dates) * .85)
q_95 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_85+1], X[:q_85+1], y[:q_85+1]

dates_val, X_val, y_val = dates[q_85:q_95+1], X[q_85:q_95+1], y[q_85:q_95+1]
dates_test, X_test, y_test = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])
print(dates_test[0])
print(dates_test[-1])


print(dates[:q_85][-1])
dates[q_85-1:][0]
# Out:
# 2024-01-22 00:00:00
# 2024-04-01 00:00:00
# 2023-08-29 00:00:00
# Timestamp('2023-08-29 00:00:00')

# %% [markdown]
# LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import layers


model = Sequential([layers.Input((window_size_n, 1)),
                    layers.LSTM(512),
                  layers.Dropout(0.001),
                    layers.Dense(512, activation='relu'),
                   # layers.Dropout(0.001),
                   layers.Dense(512, activation='relu'),
                
                    layers.Dense(512, activation='relu'),

                    layers.Dense(1)])

model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/20
# 26/26 [==============================] - 6s 172ms/step - loss: 22905.6074 - mean_absolute_error: 121.9107 - val_loss: 1056.6652 - val_mean_absolute_error: 28.3319
# Epoch 2/20
# 26/26 [==============================] - 4s 160ms/step - loss: 1146.2335 - mean_absolute_error: 24.6288 - val_loss: 103.3637 - val_mean_absolute_error: 8.0878
# Epoch 3/20
# 26/26 [==============================] - 4s 164ms/step - loss: 136.7654 - mean_absolute_error: 8.7080 - val_loss: 60.7100 - val_mean_absolute_error: 6.0129
# Epoch 4/20
# 26/26 [==============================] - 4s 150ms/step - loss: 130.9081 - mean_absolute_error: 8.5869 - val_loss: 84.2757 - val_mean_absolute_error: 7.3052
# Epoch 5/20
# 26/26 [==============================] - 5s 179ms/step - loss: 105.1930 - mean_absolute_error: 7.5714 - val_loss: 68.7441 - val_mean_absolute_error: 6.5454
# Epoch 6/20
# 26/26 [==============================] - 5s 194ms/step - loss: 106.0337 - mean_absolute_error: 7.6764 - val_loss: 48.6284 - val_mean_absolute_error: 5.2975
# Epoch 7/20
# 26/26 [==============================] - 6s 213ms/step - loss: 100.2615 - mean_absolute_error: 7.4459 - val_loss: 48.2132 - val_mean_absolute_error: 5.3269
# Epoch 8/20
# 26/26 [==============================] - 5s 193ms/step - loss: 94.6416 - mean_absolute_error: 7.0840 - val_loss: 74.4227 - val_mean_absolute_error: 6.8734
# Epoch 9/20
# 26/26 [==============================] - 5s 200ms/step - loss: 103.7075 - mean_absolute_error: 7.5419 - val_loss: 45.7943 - val_mean_absolute_error: 5.1031
# Epoch 10/20
# 26/26 [==============================] - 6s 212ms/step - loss: 97.7716 - mean_absolute_error: 7.3312 - val_loss: 48.1826 - val_mean_absolute_error: 5.1771
# Epoch 11/20
# 26/26 [==============================] - 6s 226ms/step - loss: 99.0327 - mean_absolute_error: 7.4222 - val_loss: 44.7636 - val_mean_absolute_error: 4.9481
# Epoch 12/20
# 26/26 [==============================] - 6s 220ms/step - loss: 102.9451 - mean_absolute_error: 7.3799 - val_loss: 164.3655 - val_mean_absolute_error: 11.4681
# Epoch 13/20
# 26/26 [==============================] - 6s 213ms/step - loss: 154.4703 - mean_absolute_error: 9.6568 - val_loss: 48.4614 - val_mean_absolute_error: 5.2935
# Epoch 14/20
# 26/26 [==============================] - 5s 212ms/step - loss: 96.0080 - mean_absolute_error: 7.3424 - val_loss: 46.5316 - val_mean_absolute_error: 5.0871
# Epoch 15/20
# 26/26 [==============================] - 5s 209ms/step - loss: 92.0640 - mean_absolute_error: 6.9898 - val_loss: 43.7434 - val_mean_absolute_error: 4.8671
# Epoch 16/20
# 26/26 [==============================] - 6s 219ms/step - loss: 92.9353 - mean_absolute_error: 7.0788 - val_loss: 50.6488 - val_mean_absolute_error: 5.4088
# Epoch 17/20
# 26/26 [==============================] - 6s 217ms/step - loss: 128.9977 - mean_absolute_error: 8.5978 - val_loss: 51.7063 - val_mean_absolute_error: 5.4299
# Epoch 18/20
# 26/26 [==============================] - 6s 217ms/step - loss: 95.4494 - mean_absolute_error: 7.1391 - val_loss: 48.8569 - val_mean_absolute_error: 5.3146
# Epoch 19/20
# 26/26 [==============================] - 5s 186ms/step - loss: 100.0122 - mean_absolute_error: 7.3823 - val_loss: 72.9689 - val_mean_absolute_error: 6.8127
# Epoch 20/20
# 26/26 [==============================] - 4s 171ms/step - loss: 101.2637 - mean_absolute_error: 7.3654 - val_loss: 44.3218 - val_mean_absolute_error: 4.9162

# %%
'''
model2 = Sequential([layers.Input((50, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                   layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)
'''
# Out:
# '\nmodel2 = Sequential([layers.Input((50, 1)),\n                    layers.LSTM(64),\n                    layers.Dense(32, activation=\'relu\'),\n                   layers.Dense(32, activation=\'relu\'),\n                    layers.Dense(32, activation=\'relu\'),\n                    layers.Dense(1)])\n\nmodel.compile(loss="mse",\n              optimizer=Adam(learning_rate=0.001),\n              metrics=[\'mean_absolute_error\'])\n\nmodel.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)\n'

# %% [markdown]
# How Model Perform on training data

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 26/26 [==============================] - 2s 57ms/step

# %% [markdown]
# How model performs on validation data

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 41ms/step

# %% [markdown]
# How model performs on Testing data

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

a=len(y_test)

s=0
for i in range(a):
  s+=(y_test[i]-test_predictions[i])**2

  print(dates_test[i],"  .|. ",y_test[i],"|",test_predictions[i],(y_test[i]-(y_test[i-1]),test_predictions[i]-test_predictions[i]))
print((s**(1/2))/a)
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2024-01-22 00:00:00   .|.  208.8 | 213.30913 (37.56241, 0.0)
# 2024-01-23 00:00:00   .|.  209.14 | 210.04285 (0.33999634, 0.0)
# 2024-01-24 00:00:00   .|.  207.83 | 210.41754 (-1.3099976, 0.0)
# 2024-01-25 00:00:00   .|.  182.63 | 209.22513 (-25.199997, 0.0)
# 2024-01-26 00:00:00   .|.  183.25 | 184.2024 (0.6199951, 0.0)
# 2024-01-29 00:00:00   .|.  190.93 | 185.6689 (7.6799927, 0.0)
# 2024-01-30 00:00:00   .|.  191.59 | 194.4729 (0.66000366, 0.0)
# 2024-01-31 00:00:00   .|.  187.29 | 194.43954 (-4.300003, 0.0)
# 2024-02-01 00:00:00   .|.  188.86 | 189.63736 (1.5700073, 0.0)
# 2024-02-02 00:00:00   .|.  187.91 | 191.43309 (-0.94999695, 0.0)
# 2024-02-05 00:00:00   .|.  181.06 | 190.60847 (-6.850006, 0.0)
# 2024-02-06 00:00:00   .|.  185.1 | 183.55841 (4.0400085, 0.0)
# 2024-02-07 00:00:00   .|.  187.58 | 187.95631 (2.4799957, 0.0)
# 2024-02-08 00:00:00   .|.  189.56 | 190.5981 (1.9799957, 0.0)
for i in range(len(val_predictions)):
  row_list+=[["TSLA",dates_val[i],val_predictions[i],y_val[i],False]]
for i in range(len(test_predictions)):
  row_list+=[["TSLA",dates_test[i],test_predictions[i],y_test[i],True]]

print(row_list[:5])
with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Tesla/TSLA_Stock_ML_CLOSE.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","date","Expected","Actual","isFuture"])
     writer.writerows(row_list)
# Out:
# [['TSLA', Timestamp('2020-05-15 00:00:00'), 56.81243, 53.278, False], ['TSLA', Timestamp('2020-05-18 00:00:00'), 56.662735, 54.242, False], ['TSLA', Timestamp('2020-05-19 00:00:00'), 57.514095, 53.867332, False], ['TSLA', Timestamp('2020-05-20 00:00:00'), 57.24627, 54.370667, False], ['TSLA', Timestamp('2020-05-21 00:00:00'), 57.695522, 55.173332, False]]

# %%
'''
from copy import deepcopy
last_window = deepcopy(X_test[-1])
last_date=dates_test[-1]
next_prediction = model.predict(np.array([last_window])).flatten()
next_prediction2= model2.predict(np.array([last_window])).flatten()
next_date=last_date+datetime.timedelta(1)
print(last_date,"|",last_window)
print(next_date ,"|" ,next_prediction, "||||",next_prediction2)

print(["1","2","3","4"][1:])
'''
# Out:
# '\nfrom copy import deepcopy\nlast_window = deepcopy(X_test[-1])\nlast_date=dates_test[-1]\nnext_prediction = model.predict(np.array([last_window])).flatten()\nnext_prediction2= model2.predict(np.array([last_window])).flatten()\nnext_date=last_date+datetime.timedelta(1)\nprint(last_date,"|",last_window)\nprint(next_date ,"|" ,next_prediction, "||||",next_prediction2)\n\nprint(["1","2","3","4"][1:])\n'

# %%
data_dict_close=dict()
for i in data_list_clean:
  data_dict_close[i[0]]=i[4]
print(data_dict_close["2023-11-16"])

print(data_dict_close)
# Out:
# 233.58999633789062
# {'2020-04-01': 32.104000091552734, '2020-04-02': 30.29800033569336, '2020-04-03': 32.000667572021484, '2020-04-06': 34.41600036621094, '2020-04-07': 36.36333465576172, '2020-04-08': 36.589332580566406, '2020-04-09': 38.20000076293945, '2020-04-13': 43.39666748046875, '2020-04-14': 47.32600021362305, '2020-04-15': 48.65533447265625, '2020-04-16': 49.680667877197266, '2020-04-17': 50.259334564208984, '2020-04-20': 49.75733184814453, '2020-04-21': 45.781333923339844, '2020-04-22': 48.807334899902344, '2020-04-23': 47.04199981689453, '2020-04-24': 48.34333419799805, '2020-04-27': 53.25, '2020-04-28': 51.27466583251953, '2020-04-29': 53.367332458496094, '2020-04-30': 52.12533187866211, '2020-05-01': 46.75466537475586, '2020-05-04': 50.74599838256836, '2020-05-05': 51.2140007019043, '2020-05-06': 52.172000885009766, '2020-05-07': 52.00266647338867, '2020-05-08': 54.62799835205078, '2020-05-11': 54.08599853515625, '2020-05-12': 53.96066665649414, '2020-05-13': 52.73066711425781, '2020-05-14': 53.55533218383789, '2020-05-15': 53.27799987792969, '2020-05-18': 54.242000579833984, '2020-05-19': 53.867332458496094, '2020-05-20': 54.37066650390625, '2020-05-21': 55.17333221435547, '2020-05-22': 54.45866775512695, '2020-05-26': 54.591331481933594, '2020-05-27': 54.68199920654297, '2
day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict200day+=[float(data_dict_close[i])]

#100 days
dict100day=[]
date_100_day_back= last_future_date-datetime.timedelta(100)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_100_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict100day+=[float(data_dict_close[i])]


#50 days
dict50day=[]
date_50_day_back= last_future_date-datetime.timedelta(50)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_50_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict50day+=[float(data_dict_close[i])]


print(dict200day[:5])
avg200day=sum(dict200day)/len(dict200day)
avg100day=sum(dict100day)/len(dict100day)
avg50day=sum(dict50day)/len(dict50day)

row_stock=["TSLA",week52high,week52low,avg200day,avg100day,avg50day]

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Stock_Data_CLOSE.csv', 'a', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])
     writer.writerow(row_stock)
# Out:
# [276.5400085449219, 274.42999267578125, 269.6099853515625, 269.7900085449219, 271.989990234375]

# %% [markdown]
# How Model Is performing?

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# # **WORK IN PROGRESS!!**

# %%
print(next_prediction)
a=np.array(next_prediction)
print(a.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(next_prediction)
#       2 a=np.array(next_prediction)
#       3 print(a.shape)
#
# NameError: name 'next_prediction' is not defined

# %%
b=np.append(last_window[1:],next_prediction)
print(last_window.shape)
p=b.reshape(window_size_n,1)
print(p.shape)
# Out:
# (25, 1)
# (25, 1)

# %%
'''
nextp= model.predict(np.array([p]))
nextdatep=next_date+datetime.timedelta(1)
d=[]+(nextp)
print(nextdatep,"|",nextp)
for i in range(7):
  p=np.append(p[1:],nextp)
  p=p.reshape(window_size_n,1)

  nextp=model.predict(np.array([p])).flatten()

  nextdatep+=datetime.timedelta(1)
  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:
    nextdatep+=datetime.timedelta(1)
  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])
  d+=(nextp)
print(p)
print(d)
'''
# Out:
# '\nnextp= model.predict(np.array([p]))\nnextdatep=next_date+datetime.timedelta(1)\nd=[]+(nextp)\nprint(nextdatep,"|",nextp)\nfor i in range(7):\n  p=np.append(p[1:],nextp)\n  p=p.reshape(window_size_n,1)\n\n  nextp=model.predict(np.array([p])).flatten()\n\n  nextdatep+=datetime.timedelta(1)\n  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:\n    nextdatep+=datetime.timedelta(1)\n  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])\n  d+=(nextp)\nprint(p)\nprint(d)\n'

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
print(test_predictions[1],dates_test[1])
print(df.loc['2023-09-08'])
# Out:
# 181.90137 2024-01-05 00:00:00
# Close    178.179993
# Name: 2023-09-08 00:00:00, dtype: float64
