# %% [markdown]
# Getting Data

# %%
import yfinance as yf

# %%
import yfinance as yf
data = yf.download("PEP", period="25mo")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Data Format

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print(data.shape)
# Out:
# (524, 6)

# %%
data.to_csv("//Users/shubham/Desktop/compsci_4zp6a_capstone/content/PEP_demo.csv", sep='\t')

# %% [markdown]
# Data Cleaning

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['Low'][0:10]
data['Low'][-1:]
# Out:
# Date
# 2024-03-28 00:00:00-04:00    174.369995
# Name: Low, dtype: float64

# %%
data.T
# Out:
# Date       2022-02-28 00:00:00-05:00  2022-03-01 00:00:00-05:00  \
# Open                    1.640400e+02               1.630700e+02
# High                    1.652100e+02               1.644000e+02
# Low                     1.614100e+02               1.613000e+02
# Close                   1.637400e+02               1.622700e+02
# Adj Close               1.538490e+02               1.524678e+02
# Volume                  7.677000e+06               5.107900e+06
#
# Date       2022-03-02 00:00:00-05:00  2022-03-03 00:00:00-05:00  \
# Open                    1.629800e+02               1.639700e+02
# High                    1.658200e+02               1.651900e+02
# Low                     1.624900e+02               1.628000e+02
# Close                   1.645200e+02               1.632700e+02
# Adj Close               1.545818e+02               1.544163e+02
# Volume                  5.452100e+06               5.352200e+06
#
# Date       2022-03-04 00:00:00-05:00  2022-03-07 00:00:00-05:00  \
# Open                    1.620000e+02               1.640700e+02
# High                    1.665000e+02               1.651500e+02
# Low                     1.609200e+02               1.621300e+02
# Close                   1.657500e+02               1.624500e+02
# Adj Close               1.567618e+02               1.536408e+02
# Volume                  6.340300e+06               6.319500e+06
#
# Date       2022-03-08 00:00:00-05:00  2022-03-09 00:00:00-05:00  \
# Open                    1.623800e+02               1.598100e+02
# High                    1.639700e+02               1.600600e+02
# Low                     1.576900e+02               1.564000e+02
# Close                   1.578700e+02               1.574000e+02
# Adj Close               1.493092e+02               1.488646e+02
# Volume                  6.163700e+06               5.764900e+06
#
# Date       2022-03-10 00:00:00-05:00  2022-03-11 00:00:00-05:00  ...  \
# Open                    1.557900e+02               1.554500e+02  ...
# High                    1.562500e+02               1.568900e+02  ...
# Low                     1.533700e+02               1.534800e+02  ...
# Close                   1.545100e+02               1.537300e+02  ...
# Adj Close               1.461313e+02               1.453936e+02  ...
# Volume                  6.103700e+06               4.762600e+06  ...
#
# Date       2024-03-15 00:00:00-04:00  2024-03-18 00:00:00-04:00  \
# Open                    1.650600e+02               1.670500e+02
# High                    1.653800e+02               1.721800e+02
# Low                     1.636400e+02               1.669500e+02
# Close                   1.646600e+02               1.712600e+02
# Adj Close               1.646600e+02               1.712600e+02
# Volume                  2.188120e+07               1.047850e+07
#
# Date       2024-03-19 00:00:00-04:00  2024-03-20 00:00:00-04:00  \
# Open                    1.711000e+02               1.723000e+02
# High                    1.726500e+02               1.731000e+02
# Low                     1.710000e+02               1.711200e+02
# Close                   1.718000e+02               1.718600e+02
# Adj Close               1.718000e+02               1.718600e+02
# Volume                  7.653700e+06               5.046700e+06
#
# Date       2024-03-21 00:00:00-04:00  2024-03-22 00:00:00-04:00  \
# Open                    1.719200e+02               1.730200e+02
# High                    1.734200e+02               1.731000e+02
# Low                     1.710500e+02               1.717600e+02
# Close                   1.724500e+02               1.720200e+02
# Adj Close               1.724500e+02               1.720200e+02
# Volume                  4.343000e+06               4.106400e+06
#
# Date       2024-03-25 00:00:00-04:00  2024-03-26 00:00:00-04:00  \
# Open                    1.722000e+02               1.721700e+02
# High                    1.730900e+02               1.729700e+02
# Low                     1.721100e+02               1.718200e+02
# Close                   1.726000e+02               1.727300e+02
# Adj Close               1.726000e+02               1.727300e+02
# Volume                  3.941900e+06               4.593000e+06
#
# Date       2024-03-27 00:00:00-04:00  2024-03-28 00:00:00-04:00
# Open                    1.740000e+02               1.747600e+02
# High                    1.746900e+02               1.758100e+02
# Low                     1.730500e+02               1.743700e+02
# Close                   1.735700e+02               1.750100e+02
# Adj Close               1.735700e+02               1.750100e+02
# Volume                  4.911300e+06               5.710400e+06
#
# [6 rows x 524 columns]

# %%
import numpy
import pandas as pd
import csv
from datetime import datetime

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/content/PEP_demo.csv', newline='') as f:
    reader = csv.reader(f)
    data_list = list(reader)
   
data_list_clean=[]
list_clean=[]
k=0
print(str(data_list[0][0]))
for i in data_list[1:]:
  list_clean+=[str(i[0]).split("\t")]
  
for j in list_clean:
    
  date=(j[0][:10])
   
  a=[date]+[float(j[1])]+[float(j[2])]+[float(j[3])]+[float(j[4])]+[float(j[5])]+[float(j[6])]
  data_list_clean+=[a]
   

print(len(data_list))
print(len(data_list_clean))
# Out:
# Date	Open	High	Low	Close	Adj Close	Volume
# 525
# 524

# %%
df=pd.DataFrame(data_list_clean[1:],columns=data_list[0][0].split("\t"))
print(df.dtypes)
df_fil=df[['Date','Low']]

print(df_fil[:10])
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date         Low
# 0  2022-03-01  161.300003
# 1  2022-03-02  162.490005
# 2  2022-03-03  162.800003
# 3  2022-03-04  160.919998
# 4  2022-03-07  162.130005
# 5  2022-03-08  157.690002
# 6  2022-03-09  156.399994
# 7  2022-03-10  153.369995
# 8  2022-03-11  153.479996
# 9  2022-03-14  154.500000

# %%
print(data_list_clean)
# Out:
# [['2022-02-28', 164.0399932861328, 165.2100067138672, 161.41000366210938, 163.74000549316406, 153.84896850585938, 7677000.0], ['2022-03-01', 163.07000732421875, 164.39999389648438, 161.3000030517578, 162.27000427246094, 152.46775817871094, 5107900.0], ['2022-03-02', 162.97999572753906, 165.82000732421875, 162.49000549316406, 164.52000427246094, 154.5818328857422, 5452100.0], ['2022-03-03', 163.97000122070312, 165.19000244140625, 162.8000030517578, 163.27000427246094, 154.4163360595703, 5352200.0], ['2022-03-04', 162.0, 166.5, 160.9199981689453, 165.75, 156.76182556152344, 6340300.0], ['2022-03-07', 164.07000732421875, 165.14999389648438, 162.1300048828125, 162.4499969482422, 153.64080810546875, 6319500.0], ['2022-03-08', 162.3800048828125, 163.97000122070312, 157.69000244140625, 157.8699951171875, 149.30917358398438, 6163700.0], ['2022-03-09', 159.80999755859375, 160.05999755859375, 156.39999389648438, 157.39999389648438, 148.8646240234375, 5764900.0], ['2022-03-10', 155.7899932861328, 156.25, 153.3699951171875, 154.50999450683594, 146.13134765625, 6103700.0], ['2022-03-11', 155.4499969482422, 156.88999938964844, 153.47999572753906, 153.72999572753906, 145.39364624023438, 4762600.0], ['2022-03-14', 155.14999389648438, 157.8000030517578, 154.5, 155.88999938964844, 147.4365234375, 6075600.0], ['2022-03-15', 157.32000732421875, 159.5, 156.8300018310547, 159.0, 150.37786865234375, 6203400.0], ['2022-03-16', 158.41000366210938, 159.99000549316406, 157.0399932861328, 159.6999969482422, 151.03990173339844, 6299000.0], ['2022-03-17', 159.8300018310547, 161.6300048828125, 159.3000030517578, 160.94000244140625, 152.2126922607422, 3587600.0], ['2022-03-18', 161.3800048828125, 162.92999267578125, 160.05999755859375, 162.7899932861328, 153.96234130859375, 12123000.0], ['2022-03-21', 162.27000427246094, 163.80999755859375, 161.07000732421875, 162.55999755859375, 153.74484252929688, 5122600.0], ['2022-03-22', 162.83999633789062, 164.77000427246094, 162.22999572753906, 164.33999633789062, 155.4282989501953, 5779200.0], ['2022-03-23', 164.25, 165.27999877929688, 162.6300048828125, 163.47999572753906, 154.6149139404297, 4533700.0], ['2022-03-24', 164.05999755859375, 164.72999572753906, 163.27000427246094, 164.47000122070312, 155.55125427246094, 3160300.0], ['2022-03-25', 164.42999267578125, 165.89999389648438, 164.42999267578125, 165.24000549316406, 156.2794952392578, 4146800.0], ['2022-03-28', 165.10000610351562, 165.77000427246094, 163.7100067138672, 165.72999572753906, 156.742919921875, 4308000.0], ['2022-03-29', 167.2899932861328, 168.5800018310547, 166.3699951171875, 168.19000244140625, 159.06954956054688, 4440400.0], ['2022-03-30', 168.10000610351562, 168.24000549316406, 166.1199951171875, 167.9600067138672, 158.85198974609375, 3871500.0], ['2022-03-31', 168.3699951171875, 169.3000030517578, 167.27000427246094, 167.3800048828125, 158.30348205566406, 6076200.0], ['2022-04-01', 167.88999938964844, 169.92999267578125, 167.3699951171875, 169.75999450683594, 160.5543975830078, 3239600.0], ['2022-04-04', 169.11000061035156, 169.38999938964844, 167.4499969482422, 169.32000732421875, 160.1382598876953, 3759900.0], ['2022-04-05', 168.32000732421875, 171.3800048828125, 168.32000732421875, 169.5, 160.30850219726562, 4480700.0], ['2022-04-06', 169.9199981689453, 172.6999969482422, 169.49000549316406, 172.38999938964844, 163.04176330566406, 4294800.0], ['2022-04-07', 172.02999877929688, 173.27999877929688, 170.77999877929688, 172.5500030517578, 163.19309997558594, 5041600.0], ['2022-04-08', 172.99000549316406, 173.69000244140625, 171.58999633789062, 173.1300048828125, 163.7416534423828, 3883100.0], ['2022-04-11', 173.61000061035156, 174.97000122070312, 172.32000732421875, 172.60000610351562, 163.2404022216797, 3825100.0], ['2022-04-12', 173.77999877929688, 174.64999389648438, 172.6300048828125, 173.3000030517578, 163.90245056152344, 3924300.0], ['2022-04-13', 173.5800018310547, 173.82000732421875, 171.72999572753906, 173.0, 163.61871337890625, 4394000 ...

# %%
import datetime
def str_to_datetime(s):
  
  split=s.split('-')
  year,month,day=int(split[0]),int(split[1]
  ),int(split[2])
  return datetime.datetime(year=year,month=month,day=day)

df_fil['Date']=df_fil['Date'].apply(str_to_datetime)
# Out:
# /var/folders/dj/2ct0t4413vdb_zyk_9q62gs40000gn/T/ipykernel_20058/1826438051.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Date']=df_fil['Date'].apply(str_to_datetime)

# %%
df_fil['Date']
# Out:
# 0     2022-03-01
# 1     2022-03-02
# 2     2022-03-03
# 3     2022-03-04
# 4     2022-03-07
#          ...
# 518   2024-03-22
# 519   2024-03-25
# 520   2024-03-26
# 521   2024-03-27
# 522   2024-03-28
# Name: Date, Length: 523, dtype: datetime64[ns]

# %%
df_fil.index=df_fil.pop('Date')
print(df_fil)
# Out:
#                    Low
# Date
# 2022-03-01  161.300003
# 2022-03-02  162.490005
# 2022-03-03  162.800003
# 2022-03-04  160.919998
# 2022-03-07  162.130005
# ...                ...
# 2024-03-22  171.759995
# 2024-03-25  172.110001
# 2024-03-26  171.820007
# 2024-03-27  173.050003
# 2024-03-28  174.369995
#
# [523 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df=df_fil
plt.plot(df.index, df['Low'])
print(df[:-10])
# Out:
#                    Low
# Date
# 2022-03-01  161.300003
# 2022-03-02  162.490005
# 2022-03-03  162.800003
# 2022-03-04  160.919998
# 2022-03-07  162.130005
# ...                ...
# 2024-03-08  162.089996
# 2024-03-11  163.309998
# 2024-03-12  163.960007
# 2024-03-13  164.740005
# 2024-03-14  164.199997
#
# [513 rows x 1 columns]

# %%
str(df_fil.index[-51])[:-9]
# Out:
# '2024-01-17'

# %% [markdown]
# Reshaping data for model

# %%
import numpy as np
window_size_n=30
startdate= str(df_fil.index[window_size_n])[:-9]
lastdate=str(df_fil.index[-1])[:-9]


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Low'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                startdate,
                                lastdate,
                                window_size_n)
windowed_df
# Out:
#     Target Date   Target-30   Target-29   Target-28   Target-27   Target-26  \
# 0    2022-04-12  161.300003  162.490005  162.800003  160.919998  162.130005
# 1    2022-04-13  162.490005  162.800003  160.919998  162.130005  157.690002
# 2    2022-04-14  162.800003  160.919998  162.130005  157.690002  156.399994
# 3    2022-04-18  160.919998  162.130005  157.690002  156.399994  153.369995
# 4    2022-04-19  162.130005  157.690002  156.399994  153.369995  153.479996
# ..          ...         ...         ...         ...         ...         ...
# 488  2024-03-22  171.410004  166.970001  167.199997  167.240005  166.059998
# 489  2024-03-25  166.970001  167.199997  167.240005  166.059998  166.679993
# 490  2024-03-26  167.199997  167.240005  166.059998  166.679993  165.679993
# 491  2024-03-27  167.240005  166.059998  166.679993  165.679993  167.190002
# 492  2024-03-28  166.059998  166.679993  165.679993  167.190002  167.860001
#
#       Target-25   Target-24   Target-23   Target-22  ...    Target-9  \
# 0    157.690002  156.399994  153.369995  153.479996  ...  166.119995
# 1    156.399994  153.369995  153.479996  154.500000  ...  167.270004
# 2    153.369995  153.479996  154.500000  156.830002  ...  167.369995
# 3    153.479996  154.500000  156.830002  157.039993  ...  167.449997
# 4    154.500000  156.830002  157.039993  159.300003  ...  168.320007
# ..          ...         ...         ...         ...  ...         ...
# 488  166.679993  165.679993  167.190002  167.860001  ...  163.309998
# 489  165.679993  167.190002  167.860001  166.100006  ...  163.960007
# 490  167.190002  167.860001  166.100006  167.800003  ...  164.740005
# 491  167.860001  166.100006  167.800003  167.710007  ...  164.199997
# 492  166.100006  167.800003  167.710007  167.350006  ...  163.639999
#
#        Target-8    Target-7    Target-6    Target-5    Target-4    Target-3  \
# 0    167.270004  167.369995  167.449997  168.320007  169.490005  170.779999
# 1    167.369995  167.449997  168.320007  169.490005  170.779999  171.589996
# 2    167.449997  168.320007  169.490005  170.779999  171.589996  172.320007
# 3    168.320007  169.490005  170.779999  171.589996  172.320007  172.630005
# 4    169.490005  170.779999  171.589996  172.320007  172.630005  171.729996
# ..          ...         ...         ...         ...         ...         ...
# 488  163.960007  164.740005  164.199997  163.639999  166.949997  171.000000
# 489  164.740005  164.199997  163.639999  166.949997  171.000000  171.119995
# 490  164.199997  163.639999  166.949997  171.000000  171.119995  171.050003
# 491  163.639999  166.949997  171.000000  171.119995  171.050003  171.759995
# 492  166.949997  171.000000  171.119995  171.050003  171.759995  172.110001
#
#        Target-2    Target-1      Target
# 0    171.589996  172.320007  172.630005
# 1    172.320007  172.630005  171.729996
# 2    172.630005  171.729996  171.759995
# 3    171.729996  171.759995  169.960007
# 4    171.759995  169.960007  169.839996
# ..          ...         ...         ...
# 488  171.119995  171.050003  171.759995
# 489  171.050003  171.759995  172.110001
# 490  171.759995  172.110001  171.820007
# 491  172.110001  171.820007  173.050003
# 492  171.820007  173.050003  174.369995
#
# [493 rows x 32 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
print(X)
# Out:
# [[[161.3 ]
#   [162.49]
#   [162.8 ]
#   ...
#   [170.78]
#   [171.59]
#   [172.32]]
#
#  [[162.49]
#   [162.8 ]
#   [160.92]
#   ...
#   [171.59]
#   [172.32]
#   [172.63]]
#
#  [[162.8 ]
#   [160.92]
#   [162.13]
#   ...
#   [172.32]
#   [172.63]
#   [171.73]]
#
#  ...
#
#  [[167.2 ]
#   [167.24]
#   [166.06]
#   ...
#   [171.05]
#   [171.76]
#   [172.11]]
#
#  [[167.24]
#   [166.06]
#   [166.68]
#   ...
#   [171.76]
#   [172.11]
#   [171.82]]
#
#  [[166.06]
#   [166.68]
#   [165.68]
#   ...
#   [172.11]
#   [171.82]
#   [173.05]]]

# %% [markdown]
# Splitting data into training validation and testing

# %%
q_85 = int(len(dates) * .85)
q_95 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_85+1], X[:q_85+1], y[:q_85+1]

dates_val, X_val, y_val = dates[q_85:q_95+1], X[q_85:q_95+1], y[q_85:q_95+1]
dates_test, X_test, y_test = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])
print(dates_test[0])
print(dates_test[-1])


print(dates[:q_85][-1])
dates[q_85-1:][0]
# Out:
# 2024-02-23 00:00:00
# 2024-03-28 00:00:00
# 2023-12-11 00:00:00
# Timestamp('2023-12-11 00:00:00')

# %% [markdown]
# LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import layers


model = Sequential([layers.Input((window_size_n, 1)),
                    layers.LSTM(256),
                  layers.Dropout(0.001),
                    layers.Dense(256, activation='relu'),
                   # layers.Dropout(0.001),
                   layers.Dense(256, activation='relu'),
                
                    layers.Dense(256, activation='relu'),

                    layers.Dense(1)])
model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/150
# 14/14 [==============================] - 1s 42ms/step - loss: 27560.7051 - mean_absolute_error: 165.6080 - val_loss: 16919.5469 - val_mean_absolute_error: 130.0618
# Epoch 2/150
# 14/14 [==============================] - 0s 27ms/step - loss: 6872.2227 - mean_absolute_error: 71.9065 - val_loss: 3465.0605 - val_mean_absolute_error: 58.8295
# Epoch 3/150
# 14/14 [==============================] - 0s 28ms/step - loss: 789.5717 - mean_absolute_error: 24.3367 - val_loss: 123.3147 - val_mean_absolute_error: 10.9441
# Epoch 4/150
# 14/14 [==============================] - 0s 29ms/step - loss: 215.8627 - mean_absolute_error: 12.2940 - val_loss: 132.4850 - val_mean_absolute_error: 11.3575
# Epoch 5/150
# 14/14 [==============================] - 0s 28ms/step - loss: 108.7002 - mean_absolute_error: 8.3827 - val_loss: 66.2041 - val_mean_absolute_error: 7.9204
# Epoch 6/150
# 14/14 [==============================] - 0s 28ms/step - loss: 84.3505 - mean_absolute_error: 7.6659 - val_loss: 26.8114 - val_mean_absolute_error: 4.8565
# Epoch 7/150
# 14/14 [==============================] - 0s 29ms/step - loss: 76.5349 - mean_absolute_error: 7.3220 - val_loss: 60.8388 - val_mean_absolute_error: 7.5751
# Epoch 8/150
# 14/14 [==============================] - 0s 29ms/step - loss: 77.9057 - mean_absolute_error: 7.3766 - val_loss: 56.5801 - val_mean_absolute_error: 7.2889
# Epoch 9/150
# 14/14 [==============================] - 0s 29ms/step - loss: 75.4544 - mean_absolute_error: 7.2474 - val_loss: 42.9018 - val_mean_absolute_error: 6.2817
# Epoch 10/150
# 14/14 [==============================] - 0s 29ms/step - loss: 74.2518 - mean_absolute_error: 7.1715 - val_loss: 55.5721 - val_mean_absolute_error: 7.2232
# Epoch 11/150
# 14/14 [==============================] - 0s 31ms/step - loss: 69.2597 - mean_absolute_error: 7.0235 - val_loss: 37.1397 - val_mean_absolute_error: 5.8115
# Epoch 12/150
# 14/14 [==============================] - 0s 28ms/step - loss: 67.9520 - mean_absolute_error: 6.8831 - val_loss: 50.3342 - val_mean_absolute_error: 6.8698
# Epoch 13/150
# 14/14 [==============================] - 0s 29ms/step - loss: 62.3417 - mean_absolute_error: 6.5250 - val_loss: 20.6789 - val_mean_absolute_error: 4.2149
# Epoch 14/150
# 14/14 [==============================] - 0s 29ms/step - loss: 75.1919 - mean_absolute_error: 7.1920 - val_loss: 40.5304 - val_mean_absolute_error: 6.1009
# Epoch 15/150
# 14/14 [==============================] - 0s 31ms/step - loss: 72.1815 - mean_absolute_error: 7.0554 - val_loss: 33.9244 - val_mean_absolute_error: 5.5347
# Epoch 16/150
# 14/14 [==============================] - 0s 30ms/step - loss: 73.1720 - mean_absolute_error: 7.1129 - val_loss: 36.2697 - val_mean_absolute_error: 5.7469
# Epoch 17/150
# 14/14 [==============================] - 0s 30ms/step - loss: 73.2149 - mean_absolute_error: 7.1800 - val_loss: 59.2070 - val_mean_absolute_error: 7.4841
# Epoch 18/150
# 14/14 [==============================] - 0s 30ms/step - loss: 67.3959 - mean_absolute_error: 6.8764 - val_loss: 28.8717 - val_mean_absolute_error: 5.0829
# Epoch 19/150
# 14/14 [==============================] - 0s 30ms/step - loss: 61.1680 - mean_absolute_error: 6.4961 - val_loss: 29.3609 - val_mean_absolute_error: 5.1339
# Epoch 20/150
# 14/14 [==============================] - 0s 31ms/step - loss: 50.2347 - mean_absolute_error: 5.8461 - val_loss: 14.6536 - val_mean_absolute_error: 3.5175
# Epoch 21/150
# 14/14 [==============================] - 0s 31ms/step - loss: 38.1852 - mean_absolute_error: 5.0216 - val_loss: 2.8181 - val_mean_absolute_error: 1.3080
# Epoch 22/150
# 14/14 [==============================] - 0s 31ms/step - loss: 32.7368 - mean_absolute_error: 4.5776 - val_loss: 14.1789 - val_mean_absolute_error: 3.4636
# Epoch 23/150
# 14/14 [==============================] - 0s 30ms/step - loss: 32.1857 - mean_absolute_error: 4.5756 - val_loss: 52.5070 - val_mean_absolute_error: 7.0692
# Epoch 24/150
# 14/14 [==============================] - 0s 35ms/step - loss: 32.5036 - mean_absolute_error: 4.5798 - val_loss: 2.4345 - val_mean_absolute_error: 1.2398
# Epoch 25/150
# 14/14 [==============================] - 0s 30ms/step - loss: 18.6229 - mean_absolute_error: 3.3980 - val_loss: 3.7960 - val_mean_absolute_error: 1.6318
# Epoch 26/150
# 14/14 [==============================] - 0s 31ms/step - loss: 16.1413 - mean_absolute_error: 3.2125 - val_loss: 12.1893 - val_mean_absolute_error: 3.2268
# Epoch 27/150
# 14/14 [==============================] - 0s 31ms/step - loss: 18.9010 - mean_absolute_error: 3.5550 - val_loss: 28.5701 - val_mean_absolute_error: 5.1480
# Epoch 28/150
# 14/14 [==============================] - 0s 34ms/step - loss: 18.1869 - mean_absolute_error: 3.3537 - val_loss: 5.1639 - val_mean_absolute_error: 2.0016
# Epoch 29/150
# 14/14 [==============================] - 0s 29ms/step - loss: 12.0067 - mean_absolute_error: 2.7919 - val_loss: 2.4350 - val_mean_absolute_error: 1.2248
# Epoch 30/150
# 14/14 [==============================] - 0s 29ms/step - loss: 13.9488 - mean_absolute_error: 3.0043 - val_loss: 2.2399 - val_mean_absolute_error: 1.2041
# Epoch 31/150
# 14/14 [==============================] - 0s 30ms/step - loss: 13.1298 - mean_absolute_error: 2.9118 - val_loss: 4.9180 - val_mean_absolute_error: 1.9376
# Epoch 32/150
# 14/14 [==============================] - 0s 32ms/step - loss: 11.4645 - mean_absolute_error: 2.7181 - val_loss: 10.1369 - val_mean_absolute_error: 2.9346
# Epoch 33/150
# 14/14 [==============================] - 0s 29ms/step - loss: 10.8247 - mean_absolute_error: 2.6957 - val_loss: 3.7911 - val_mean_absolute_error: 1.6423
# Epoch 34/150
# 14/14 [==============================] - 0s 29ms/step - loss: 9.4175 - mean_absolute_error: 2.4434 - val_loss: 4.4074 - val_mean_absolute_error: 1.7382
# Epoch 35/150
# 14/14 [==============================] - 0s 30ms/step - loss: 8.7010 - mean_absolute_error: 2.3312 - val_loss: 4.1959 - val_mean_absolute_error: 1.7543
# Epoch 36/150
# 14/14 [==============================] - 0s 31ms/step - loss: 7.5146 - mean_absolute_error: 2.1630 - val_loss: 1.8907 - val_mean_absolute_error: 1.0761
# Epoch 37/150
# 14/14 [==============================] - 0s 31ms/step - loss: 8.4002 - mean_absolute_error: 2.2787 - val_loss: 1.9673 - val_mean_absolute_error: 1.0741
# Epoch 38/150
# 14/14 [==============================] - 0s 30ms/step - loss: 6.5579 - mean_absolute_error: 2.0465 - val_loss: 2.1964 - val_mean_absolute_error: 1.1274
# Epoch 39/150
# 14/14 [==============================] - 0s 30ms/step - loss: 5.7822 - mean_absolute_error: 1.8682 - val_loss: 5.1634 - val_mean_absolute_error: 1.9836
# Epoch 40/150
# 14/14 [==============================] - 0s 30ms/step - loss: 5.3827 - mean_absolute_error: 1.7836 - val_loss: 3.0725 - val_mean_absolute_error: 1.3894
# Epoch 41/150
# 14/14 [==============================] - 0s 29ms/step - loss: 5.1208 - mean_absolute_error: 1.7016 - val_loss: 2.8521 - val_mean_absolute_error: 1.3795
# Epoch 42/150
# 14/14 [==============================] - 0s 29ms/step - loss: 5.2639 - mean_absolute_error: 1.7869 - val_loss: 1.8305 - val_mean_absolute_error: 1.0037
# Epoch 43/150
# 14/14 [==============================] - 0s 31ms/step - loss: 4.5923 - mean_absolute_error: 1.6699 - val_loss: 3.6557 - val_mean_absolute_error: 1.6023
# Epoch 44/150
# 14/14 [==============================] - 0s 30ms/step - loss: 6.7435 - mean_absolute_error: 1.9770 - val_loss: 2.1324 - val_mean_absolute_error: 1.1518
# Epoch 45/150
# 14/14 [==============================] - 0s 31ms/step - loss: 5.2050 - mean_absolute_error: 1.6935 - val_loss: 10.0865 - val_mean_absolute_error: 2.9184
# Epoch 46/150
# 14/14 [==============================] - 0s 31ms/step - loss: 6.9817 - mean_absolute_error: 2.0651 - val_loss: 1.7890 - val_mean_absolute_error: 1.0379
# Epoch 47/150
# 14/14 [==============================] - 1s 37ms/step - loss: 5.4122 - mean_absolute_error: 1.7737 - val_loss: 7.0409 - val_mean_absolute_error: 2.3791
# Epoch 48/150
# 14/14 [==============================] - 0s 30ms/step - loss: 6.3486 - mean_absolute_error: 1.9381 - val_loss: 2.3586 - val_mean_absolute_error: 1.1548
# Epoch 49/150
# 14/14 [==============================] - 0s 31ms/step - loss: 4.6257 - mean_absolute_error: 1.6087 - val_loss: 4.2830 - val_mean_absolute_error: 1.7194
# Epoch 50/150
# 14/14 [==============================] - 0s 30ms/step - loss: 4.9758 - mean_absolute_error: 1.7411 - val_loss: 7.9096 - val_mean_absolute_error: 2.5624
# Epoch 51/150
# 14/14 [==============================] - 0s 30ms/step - loss: 6.7170 - mean_absolute_error: 2.0505 - val_loss: 5.0659 - val_mean_absolute_error: 1.9289
# Epoch 52/150
# 14/14 [==============================] - 0s 31ms/step - loss: 4.9296 - mean_absolute_error: 1.6764 - val_loss: 2.5443 - val_mean_absolute_error: 1.2955
# Epoch 53/150
# 14/14 [==============================] - 0s 32ms/step - loss: 3.9318 - mean_absolute_error: 1.4747 - val_loss: 1.7754 - val_mean_absolute_error: 0.9936
# Epoch 54/150
# 14/14 [==============================] - 0s 30ms/step - loss: 3.9043 - mean_absolute_error: 1.4932 - val_loss: 1.9825 - val_mean_absolute_error: 1.0196
# Epoch 55/150
# 14/14 [==============================] - 0s 31ms/step - loss: 4.4088 - mean_absolute_error: 1.6203 - val_loss: 3.7334 - val_mean_absolute_error: 1.5591
# Epoch 56/150
# 14/14 [==============================] - 0s 31ms/step - loss: 6.4928 - mean_absolute_error: 2.0718 - val_loss: 7.7994 - val_mean_absolute_error: 2.5386
# Epoch 57/150
# 14/14 [==============================] - 0s 31ms/step - loss: 7.6571 - mean_absolute_error: 2.2496 - val_loss: 1.7878 - val_mean_absolute_error: 0.9834
# Epoch 58/150
# 14/14 [==============================] - 0s 32ms/step - loss: 5.7479 - mean_absolute_error: 1.8886 - val_loss: 2.3940 - val_mean_absolute_error: 1.1657
# Epoch 59/150
# 14/14 [==============================] - 0s 31ms/step - loss: 4.5904 - mean_absolute_error: 1.6121 - val_loss: 1.7861 - val_mean_absolute_error: 1.0025
# Epoch 60/150
# 14/14 [==============================] - 0s 34ms/step - loss: 4.3490 - mean_absolute_error: 1.5789 - val_loss: 2.8165 - val_mean_absolute_error: 1.3822
# Epoch 61/150
# 14/14 [==============================] - 0s 32ms/step - loss: 3.8067 - mean_absolute_error: 1.4890 - val_loss: 1.9946 - val_mean_absolute_error: 1.1117
# Epoch 62/150
# 14/14 [==============================] - 0s 32ms/step - loss: 4.2298 - mean_absolute_error: 1.5676 - val_loss: 1.9882 - val_mean_absolute_error: 1.1093
# Epoch 63/150
# 14/14 [==============================] - 0s 33ms/step - loss: 3.7849 - mean_absolute_error: 1.4782 - val_loss: 6.4588 - val_mean_absolute_error: 2.2652
# Epoch 64/150
# 14/14 [==============================] - 0s 33ms/step - loss: 5.0079 - mean_absolute_error: 1.7366 - val_loss: 6.5031 - val_mean_absolute_error: 2.2414
# Epoch 65/150
# 14/14 [==============================] - 0s 33ms/step - loss: 4.8245 - mean_absolute_error: 1.6349 - val_loss: 2.0937 - val_mean_absolute_error: 1.0505
# Epoch 66/150
# 14/14 [==============================] - 0s 33ms/step - loss: 3.8367 - mean_absolute_error: 1.4813 - val_loss: 2.1063 - val_mean_absolute_error: 1.1492
# Epoch 67/150
# 14/14 [==============================] - 0s 35ms/step - loss: 4.0718 - mean_absolute_error: 1.5204 - val_loss: 2.1284 - val_mean_absolute_error: 1.1576
# Epoch 68/150
# 14/14 [==============================] - 0s 35ms/step - loss: 3.9562 - mean_absolute_error: 1.5233 - val_loss: 2.0976 - val_mean_absolute_error: 1.1494
# Epoch 69/150
# 14/14 [==============================] - 0s 36ms/step - loss: 3.8930 - mean_absolute_error: 1.4781 - val_loss: 1.9464 - val_mean_absolute_error: 1.0164
# Epoch 70/150
# 14/14 [==============================] - 0s 36ms/step - loss: 4.6928 - mean_absolute_error: 1.6638 - val_loss: 2.2384 - val_mean_absolute_error: 1.1981
# Epoch 71/150
# 14/14 [==============================] - 1s 36ms/step - loss: 4.3149 - mean_absolute_error: 1.6178 - val_loss: 2.6052 - val_mean_absolute_error: 1.2204
# Epoch 72/150
# 14/14 [==============================] - 1s 39ms/step - loss: 4.6330 - mean_absolute_error: 1.6382 - val_loss: 11.9709 - val_mean_absolute_error: 3.2238
# Epoch 73/150
# 14/14 [==============================] - 1s 37ms/step - loss: 8.8333 - mean_absolute_error: 2.4716 - val_loss: 3.6835 - val_mean_absolute_error: 1.5415
# Epoch 74/150
# 14/14 [==============================] - 1s 37ms/step - loss: 5.2982 - mean_absolute_error: 1.7733 - val_loss: 2.5742 - val_mean_absolute_error: 1.3084
# Epoch 75/150
# 14/14 [==============================] - 1s 38ms/step - loss: 3.9042 - mean_absolute_error: 1.4708 - val_loss: 1.9123 - val_mean_absolute_error: 1.0218
# Epoch 76/150
# 14/14 [==============================] - 1s 37ms/step - loss: 4.3704 - mean_absolute_error: 1.6229 - val_loss: 2.6497 - val_mean_absolute_error: 1.2349
# Epoch 77/150
# 14/14 [==============================] - 1s 37ms/step - loss: 5.5725 - mean_absolute_error: 1.8641 - val_loss: 2.1840 - val_mean_absolute_error: 1.0769
# Epoch 78/150
# 14/14 [==============================] - 1s 38ms/step - loss: 3.6378 - mean_absolute_error: 1.4406 - val_loss: 1.8825 - val_mean_absolute_error: 1.0264
# Epoch 79/150
# 14/14 [==============================] - 1s 39ms/step - loss: 3.5726 - mean_absolute_error: 1.4412 - val_loss: 3.9065 - val_mean_absolute_error: 1.5887
# Epoch 80/150
# 14/14 [==============================] - 1s 39ms/step - loss: 3.8987 - mean_absolute_error: 1.4749 - val_loss: 3.2019 - val_mean_absolute_error: 1.4906
# Epoch 81/150
# 14/14 [==============================] - 1s 40ms/step - loss: 4.4742 - mean_absolute_error: 1.6251 - val_loss: 2.2116 - val_mean_absolute_error: 1.0902
# Epoch 82/150
# 14/14 [==============================] - 1s 41ms/step - loss: 3.7528 - mean_absolute_error: 1.4630 - val_loss: 2.3211 - val_mean_absolute_error: 1.1234
# Epoch 83/150
# 14/14 [==============================] - 1s 39ms/step - loss: 3.7365 - mean_absolute_error: 1.4340 - val_loss: 2.0950 - val_mean_absolute_error: 1.1495
# Epoch 84/150
# 14/14 [==============================] - 1s 40ms/step - loss: 3.7295 - mean_absolute_error: 1.4472 - val_loss: 2.0720 - val_mean_absolute_error: 1.1408
# Epoch 85/150
# 14/14 [==============================] - 1s 39ms/step - loss: 4.0394 - mean_absolute_error: 1.5055 - val_loss: 1.9433 - val_mean_absolute_error: 1.0432
# Epoch 86/150
# 14/14 [==============================] - 1s 40ms/step - loss: 3.9376 - mean_absolute_error: 1.4767 - val_loss: 2.4273 - val_mean_absolute_error: 1.2580
# Epoch 87/150
# 14/14 [==============================] - 1s 40ms/step - loss: 3.7793 - mean_absolute_error: 1.4944 - val_loss: 1.9690 - val_mean_absolute_error: 1.0414
# Epoch 88/150
# 14/14 [==============================] - 1s 40ms/step - loss: 3.5354 - mean_absolute_error: 1.4007 - val_loss: 1.9503 - val_mean_absolute_error: 1.0690
# Epoch 89/150
# 14/14 [==============================] - 1s 39ms/step - loss: 3.8688 - mean_absolute_error: 1.4763 - val_loss: 1.9223 - val_mean_absolute_error: 1.0459
# Epoch 90/150
# 14/14 [==============================] - 1s 39ms/step - loss: 4.3822 - mean_absolute_error: 1.6103 - val_loss: 2.2521 - val_mean_absolute_error: 1.1043
# Epoch 91/150
# 14/14 [==============================] - 1s 40ms/step - loss: 4.2722 - mean_absolute_error: 1.5724 - val_loss: 1.9604 - val_mean_absolute_error: 1.0421
# Epoch 92/150
# 14/14 [==============================] - 1s 40ms/step - loss: 4.0125 - mean_absolute_error: 1.4938 - val_loss: 2.8139 - val_mean_absolute_error: 1.2822
# Epoch 93/150
# 14/14 [==============================] - 1s 41ms/step - loss: 4.0290 - mean_absolute_error: 1.4862 - val_loss: 1.9278 - val_mean_absolute_error: 1.0423
# Epoch 94/150
# 14/14 [==============================] - 1s 41ms/step - loss: 3.9650 - mean_absolute_error: 1.4997 - val_loss: 2.9798 - val_mean_absolute_error: 1.3216
# Epoch 95/150
# 14/14 [==============================] - 1s 41ms/step - loss: 4.4655 - mean_absolute_error: 1.6004 - val_loss: 7.8380 - val_mean_absolute_error: 2.4913
# Epoch 96/150
# 14/14 [==============================] - 1s 41ms/step - loss: 7.9579 - mean_absolute_error: 2.2454 - val_loss: 8.6413 - val_mean_absolute_error: 2.6662
# Epoch 97/150
# 14/14 [==============================] - 1s 42ms/step - loss: 5.6418 - mean_absolute_error: 1.8562 - val_loss: 3.6523 - val_mean_absolute_error: 1.6042
# Epoch 98/150
# 14/14 [==============================] - 1s 42ms/step - loss: 4.9590 - mean_absolute_error: 1.7387 - val_loss: 2.5278 - val_mean_absolute_error: 1.1994
# Epoch 99/150
# 14/14 [==============================] - 1s 42ms/step - loss: 4.4729 - mean_absolute_error: 1.6634 - val_loss: 1.9027 - val_mean_absolute_error: 1.0621
# Epoch 100/150
# 14/14 [==============================] - 1s 43ms/step - loss: 3.9464 - mean_absolute_error: 1.4891 - val_loss: 11.6336 - val_mean_absolute_error: 3.1294
# Epoch 101/150
# 14/14 [==============================] - 1s 42ms/step - loss: 6.5069 - mean_absolute_error: 1.9982 - val_loss: 4.9407 - val_mean_absolute_error: 1.9097
# Epoch 102/150
# 14/14 [==============================] - 1s 43ms/step - loss: 6.0278 - mean_absolute_error: 1.9037 - val_loss: 2.7337 - val_mean_absolute_error: 1.2578
# Epoch 103/150
# 14/14 [==============================] - 1s 43ms/step - loss: 5.6767 - mean_absolute_error: 1.8750 - val_loss: 2.2326 - val_mean_absolute_error: 1.2002
# Epoch 104/150
# 14/14 [==============================] - 1s 45ms/step - loss: 4.3524 - mean_absolute_error: 1.5656 - val_loss: 2.1294 - val_mean_absolute_error: 1.1690
# Epoch 105/150
# 14/14 [==============================] - 1s 44ms/step - loss: 4.2091 - mean_absolute_error: 1.5524 - val_loss: 5.6970 - val_mean_absolute_error: 2.0468
# Epoch 106/150
# 14/14 [==============================] - 1s 46ms/step - loss: 6.1879 - mean_absolute_error: 2.0064 - val_loss: 3.7901 - val_mean_absolute_error: 1.6339
# Epoch 107/150
# 14/14 [==============================] - 1s 46ms/step - loss: 4.6999 - mean_absolute_error: 1.6630 - val_loss: 2.0264 - val_mean_absolute_error: 1.0648
# Epoch 108/150
# 14/14 [==============================] - 1s 46ms/step - loss: 4.3087 - mean_absolute_error: 1.5797 - val_loss: 8.3781 - val_mean_absolute_error: 2.6105
# Epoch 109/150
# 14/14 [==============================] - 1s 48ms/step - loss: 6.7730 - mean_absolute_error: 2.1287 - val_loss: 14.9835 - val_mean_absolute_error: 3.6138
# Epoch 110/150
# 14/14 [==============================] - 1s 47ms/step - loss: 5.9734 - mean_absolute_error: 1.9079 - val_loss: 1.9412 - val_mean_absolute_error: 1.0499
# Epoch 111/150
# 14/14 [==============================] - 1s 47ms/step - loss: 4.4583 - mean_absolute_error: 1.5422 - val_loss: 3.0968 - val_mean_absolute_error: 1.3526
# Epoch 112/150
# 14/14 [==============================] - 1s 49ms/step - loss: 3.9876 - mean_absolute_error: 1.4489 - val_loss: 4.5422 - val_mean_absolute_error: 1.8185
# Epoch 113/150
# 14/14 [==============================] - 1s 48ms/step - loss: 3.6182 - mean_absolute_error: 1.4419 - val_loss: 4.1726 - val_mean_absolute_error: 1.6534
# Epoch 114/150
# 14/14 [==============================] - 1s 50ms/step - loss: 4.7359 - mean_absolute_error: 1.6976 - val_loss: 8.6160 - val_mean_absolute_error: 2.6526
# Epoch 115/150
# 14/14 [==============================] - 1s 49ms/step - loss: 5.4797 - mean_absolute_error: 1.8660 - val_loss: 5.2330 - val_mean_absolute_error: 1.9262
# Epoch 116/150
# 14/14 [==============================] - 1s 49ms/step - loss: 4.3167 - mean_absolute_error: 1.6445 - val_loss: 2.0883 - val_mean_absolute_error: 1.0765
# Epoch 117/150
# 14/14 [==============================] - 1s 50ms/step - loss: 3.5099 - mean_absolute_error: 1.4018 - val_loss: 2.3489 - val_mean_absolute_error: 1.1386
# Epoch 118/150
# 14/14 [==============================] - 1s 50ms/step - loss: 3.8674 - mean_absolute_error: 1.4718 - val_loss: 3.0613 - val_mean_absolute_error: 1.3411
# Epoch 119/150
# 14/14 [==============================] - 1s 53ms/step - loss: 5.2978 - mean_absolute_error: 1.7903 - val_loss: 10.5905 - val_mean_absolute_error: 2.9930
# Epoch 120/150
# 14/14 [==============================] - 1s 53ms/step - loss: 5.6976 - mean_absolute_error: 1.8403 - val_loss: 2.2646 - val_mean_absolute_error: 1.1218
# Epoch 121/150
# 14/14 [==============================] - 1s 35ms/step - loss: 3.3561 - mean_absolute_error: 1.3789 - val_loss: 5.0764 - val_mean_absolute_error: 1.8886
# Epoch 122/150
# 14/14 [==============================] - 0s 32ms/step - loss: 5.4924 - mean_absolute_error: 1.8282 - val_loss: 11.5600 - val_mean_absolute_error: 3.1468
# Epoch 123/150
# 14/14 [==============================] - 0s 32ms/step - loss: 5.4310 - mean_absolute_error: 1.7974 - val_loss: 3.4351 - val_mean_absolute_error: 1.4601
# Epoch 124/150
# 14/14 [==============================] - 0s 32ms/step - loss: 3.7710 - mean_absolute_error: 1.4590 - val_loss: 1.9745 - val_mean_absolute_error: 1.0896
# Epoch 125/150
# 14/14 [==============================] - 0s 33ms/step - loss: 5.3313 - mean_absolute_error: 1.7961 - val_loss: 3.6618 - val_mean_absolute_error: 1.5993
# Epoch 126/150
# 14/14 [==============================] - 0s 33ms/step - loss: 6.2712 - mean_absolute_error: 1.9738 - val_loss: 4.5051 - val_mean_absolute_error: 1.7505
# Epoch 127/150
# 14/14 [==============================] - 0s 34ms/step - loss: 4.4155 - mean_absolute_error: 1.6066 - val_loss: 2.0964 - val_mean_absolute_error: 1.1621
# Epoch 128/150
# 14/14 [==============================] - 0s 36ms/step - loss: 4.7614 - mean_absolute_error: 1.7159 - val_loss: 3.7171 - val_mean_absolute_error: 1.6092
# Epoch 129/150
# 14/14 [==============================] - 0s 34ms/step - loss: 9.0334 - mean_absolute_error: 2.4529 - val_loss: 8.2828 - val_mean_absolute_error: 2.5895
# Epoch 130/150
# 14/14 [==============================] - 0s 33ms/step - loss: 4.9562 - mean_absolute_error: 1.7119 - val_loss: 3.8971 - val_mean_absolute_error: 1.6534
# Epoch 131/150
# 14/14 [==============================] - 0s 35ms/step - loss: 4.3928 - mean_absolute_error: 1.6175 - val_loss: 3.6619 - val_mean_absolute_error: 1.5984
# Epoch 132/150
# 14/14 [==============================] - 0s 33ms/step - loss: 4.2797 - mean_absolute_error: 1.6069 - val_loss: 2.0408 - val_mean_absolute_error: 1.1316
# Epoch 133/150
# 14/14 [==============================] - 0s 34ms/step - loss: 4.2647 - mean_absolute_error: 1.5690 - val_loss: 8.8527 - val_mean_absolute_error: 2.6756
# Epoch 134/150
# 14/14 [==============================] - 0s 34ms/step - loss: 5.5295 - mean_absolute_error: 1.8098 - val_loss: 3.0305 - val_mean_absolute_error: 1.3364
# Epoch 135/150
# 14/14 [==============================] - 0s 33ms/step - loss: 3.6837 - mean_absolute_error: 1.4539 - val_loss: 1.9305 - val_mean_absolute_error: 1.0675
# Epoch 136/150
# 14/14 [==============================] - 0s 34ms/step - loss: 3.5631 - mean_absolute_error: 1.4199 - val_loss: 2.0496 - val_mean_absolute_error: 1.1262
# Epoch 137/150
# 14/14 [==============================] - 0s 36ms/step - loss: 3.4574 - mean_absolute_error: 1.4045 - val_loss: 2.4177 - val_mean_absolute_error: 1.2561
# Epoch 138/150
# 14/14 [==============================] - 0s 34ms/step - loss: 3.5379 - mean_absolute_error: 1.4209 - val_loss: 2.9628 - val_mean_absolute_error: 1.3158
# Epoch 139/150
# 14/14 [==============================] - 0s 33ms/step - loss: 3.8874 - mean_absolute_error: 1.5083 - val_loss: 9.2974 - val_mean_absolute_error: 2.7758
# Epoch 140/150
# 14/14 [==============================] - 0s 34ms/step - loss: 6.4526 - mean_absolute_error: 2.0345 - val_loss: 3.9139 - val_mean_absolute_error: 1.5905
# Epoch 141/150
# 14/14 [==============================] - 0s 33ms/step - loss: 7.2927 - mean_absolute_error: 2.1781 - val_loss: 2.0843 - val_mean_absolute_error: 1.0761
# Epoch 142/150
# 14/14 [==============================] - 0s 34ms/step - loss: 5.3553 - mean_absolute_error: 1.8098 - val_loss: 2.5341 - val_mean_absolute_error: 1.2922
# Epoch 143/150
# 14/14 [==============================] - 0s 35ms/step - loss: 3.8003 - mean_absolute_error: 1.4713 - val_loss: 3.4018 - val_mean_absolute_error: 1.5370
# Epoch 144/150
# 14/14 [==============================] - 0s 34ms/step - loss: 3.9629 - mean_absolute_error: 1.4915 - val_loss: 2.6006 - val_mean_absolute_error: 1.2126
# Epoch 145/150
# 14/14 [==============================] - 0s 35ms/step - loss: 3.4048 - mean_absolute_error: 1.4092 - val_loss: 1.9617 - val_mean_absolute_error: 1.0660
# Epoch 146/150
# 14/14 [==============================] - 0s 35ms/step - loss: 4.1231 - mean_absolute_error: 1.5222 - val_loss: 4.8035 - val_mean_absolute_error: 1.8190
# Epoch 147/150
# 14/14 [==============================] - 1s 38ms/step - loss: 5.1048 - mean_absolute_error: 1.7376 - val_loss: 5.5961 - val_mean_absolute_error: 2.0140
# Epoch 148/150
# 14/14 [==============================] - 1s 36ms/step - loss: 5.3002 - mean_absolute_error: 1.7958 - val_loss: 9.8767 - val_mean_absolute_error: 2.8735
# Epoch 149/150
# 14/14 [==============================] - 0s 35ms/step - loss: 7.3431 - mean_absolute_error: 2.1676 - val_loss: 2.4749 - val_mean_absolute_error: 1.1807
# Epoch 150/150
# 14/14 [==============================] - 1s 37ms/step - loss: 5.6926 - mean_absolute_error: 1.9357 - val_loss: 4.6415 - val_mean_absolute_error: 1.7829

# %% [markdown]
# How Model Perform on training data

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 14/14 [==============================] - 0s 13ms/step

# %% [markdown]
# How model performs on validation data

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 2/2 [==============================] - 0s 14ms/step

# %% [markdown]
# How model performs on Testing data

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

a=len(y_test)

s=0
for i in range(a):
  s+=(y_test[i]-test_predictions[i])**2

  print(dates_test[i],"  .|. ",y_test[i],"|",test_predictions[i],(y_test[i]-(y_test[i-1]),test_predictions[i]-test_predictions[i-1]))
print((s**(1/2))/a)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 2024-02-23 00:00:00   .|.  167.8 | 167.5267 (-6.569992, -7.0679474)
# 2024-02-26 00:00:00   .|.  167.71 | 169.68875 (-0.08999634, 2.1620483)
# 2024-02-27 00:00:00   .|.  167.35 | 169.38113 (-0.3600006, -0.3076172)
# 2024-02-28 00:00:00   .|.  166.45 | 168.93567 (-0.90000916, -0.4454651)
# 2024-02-29 00:00:00   .|.  164.91 | 168.03233 (-1.5399933, -0.9033356)
# 2024-03-01 00:00:00   .|.  163.25 | 166.45564 (-1.6600037, -1.5766907)
# 2024-03-04 00:00:00   .|.  163.6 | 164.84354 (0.3500061, -1.6121063)
# 2024-03-05 00:00:00   .|.  161.81 | 165.48349 (-1.7900085, 0.6399536)
# 2024-03-06 00:00:00   .|.  162.04 | 163.44376 (0.22999573, -2.039734)
# 2024-03-07 00:00:00   .|.  162.5 | 163.91803 (0.4600067, 0.47427368)
# 2024-03-08 00:00:00   .|.  162.09 | 164.4377 (-0.41000366, 0.5196686)
# 2024-03-11 00:00:00   .|.  163.31 | 163.87259 (1.2200012, -0.56510925)
# 2024-03-12 00:00:00   .|.  163.96 | 165.2784 (0.65000916, 1.4058075)
# 2024-03-13 00:00:00   .|.  164.74 | 165.84055 (0.7799988, 0.56214905)
# 2024-03-14 00:00:00   .|.  164.2 | 166.5756 (-0.54000854, 0.73506165)
# 2024-03-15 00:00:00   .|.  163.64 | 165.87283 (-0.55999756, -0.70277405)
# 2024-03-18 00:00:00   .|.  166.95 | 165.31876 (3.3099976, -0.55407715)
# 2024-03-19 00:00:00   .|.  171.0 | 169.07535 (4.050003, 3.7565918)
# 2024-03-20 00:00:00   .|.  171.12 | 173.04114 (0.11999512, 3.9657898)
# 2024-03-21 00:00:00   .|.  171.05 | 172.53375 (-0.069992065, -0.50738525)
# 2024-03-22 00:00:00   .|.  171.76 | 172.44327 (0.70999146, -0.09048462)
# 2024-03-25 00:00:00   .|.  172.11 | 173.29523 (0.3500061, 0.8519592)
# 2024-03-26 00:00:00   .|.  171.82 | 173.5708 (-0.2899933, 0.27557373)
# 2024-03-27 00:00:00   .|.  173.05 | 173.19864 (1.2299957, -0.37216187)
# 2024-03-28 00:00:00   .|.  174.37 | 174.59465 (1.3199921, 1.3960114)
# 0.3795052642606159

# %% [markdown]
# Extracting Data to be used by GUI

# %%
row_list=[]
for i in range(len(train_predictions)):
  row_list+=[["PEP",dates_train[i],train_predictions[i],y_train[i],False]]
for i in range(len(val_predictions)):
  row_list+=[["PEP",dates_val[i],val_predictions[i],y_val[i],False]]
for i in range(len(test_predictions)):
  row_list+=[["PEP",dates_test[i],test_predictions[i],y_test[i],True]]

print(row_list[:5])
with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Pepsico/PEP_Stock_ML_Low.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","date","Expected","Actual","isFuture"])
     writer.writerows(row_list)
# Out:
# [['PEP', Timestamp('2022-04-12 00:00:00'), 173.6924, 172.63, False], ['PEP', Timestamp('2022-04-13 00:00:00'), 173.94374, 171.73, False], ['PEP', Timestamp('2022-04-14 00:00:00'), 172.92899, 171.76, False], ['PEP', Timestamp('2022-04-18 00:00:00'), 173.11292, 169.96, False], ['PEP', Timestamp('2022-04-19 00:00:00'), 171.15927, 169.84, False]]

# %%
'''
from copy import deepcopy
last_window = deepcopy(X_test[-1])
last_date=dates_test[-1]
next_prediction = model.predict(np.array([last_window])).flatten()
next_prediction2= model2.predict(np.array([last_window])).flatten()
next_date=last_date+datetime.timedelta(1)
print(last_date,"|",last_window)
print(next_date ,"|" ,next_prediction, "||||",next_prediction2)

print(["1","2","3","4"][1:])
'''
# Out:
# '\nfrom copy import deepcopy\nlast_window = deepcopy(X_test[-1])\nlast_date=dates_test[-1]\nnext_prediction = model.predict(np.array([last_window])).flatten()\nnext_prediction2= model2.predict(np.array([last_window])).flatten()\nnext_date=last_date+datetime.timedelta(1)\nprint(last_date,"|",last_window)\nprint(next_date ,"|" ,next_prediction, "||||",next_prediction2)\n\nprint(["1","2","3","4"][1:])\n'

# %%
data_dict_close=dict()
for i in data_list_clean:
  data_dict_close[i[0]]=i[4]
print(data_dict_close["2023-11-16"])

print(data_dict_close)
# Out:
# 167.7100067138672
# {'2022-02-28': 163.74000549316406, '2022-03-01': 162.27000427246094, '2022-03-02': 164.52000427246094, '2022-03-03': 163.27000427246094, '2022-03-04': 165.75, '2022-03-07': 162.4499969482422, '2022-03-08': 157.8699951171875, '2022-03-09': 157.39999389648438, '2022-03-10': 154.50999450683594, '2022-03-11': 153.72999572753906, '2022-03-14': 155.88999938964844, '2022-03-15': 159.0, '2022-03-16': 159.6999969482422, '2022-03-17': 160.94000244140625, '2022-03-18': 162.7899932861328, '2022-03-21': 162.55999755859375, '2022-03-22': 164.33999633789062, '2022-03-23': 163.47999572753906, '2022-03-24': 164.47000122070312, '2022-03-25': 165.24000549316406, '2022-03-28': 165.72999572753906, '2022-03-29': 168.19000244140625, '2022-03-30': 167.9600067138672, '2022-03-31': 167.3800048828125, '2022-04-01': 169.75999450683594, '2022-04-04': 169.32000732421875, '2022-04-05': 169.5, '2022-04-06': 172.38999938964844, '2022-04-07': 172.5500030517578, '2022-04-08': 173.1300048828125, '2022-04-11': 172.60000610351562, '2022-04-12': 173.3000030517578, '2022-04-13': 173.0, '2022-04-14': 171.89999389648438, '2022-04-18': 170.4199981689453, '2022-04-19': 172.89999389648438, '2022-04-20': 175.47000122070312, '2022-04-21': 174.83999633789062, '2022-04-22': 172.14999389648438, '2022-04-25': 173.74000549316406, '2022-04-26': 173.3000030517578, '2022-04-27': 174.85000610351562, '2022-04-28': 177.5, '2022-04-29': 171.7100067138672, '2022-05-02': 167.75999450683594, '2022-05-03': 167.99000549316406, '2022-05-04': 173.86000061035156, '2022-05-05': 170.38999938964844, '2022-05-06': 170.41000366210938, '2022-05-09': 171.6999969482422, '2022-05-10': 171.49000549316406, '2022-05-11': 170.66000366210938, '2022-05-12': 170.39999389648438, '2022-05-13': 173.72000122070312, '2022-05-16': 175.47000122070312, '2022-05-17': 174.4600067138672, '2022-05-18': 163.64999389648438, '2022-05-19': 161.1999969482422, '2022-05-20': 162.2100067138672, '2022-05-23': 165.60000610351562, '2022-05-24': 167.82000732421875, '2022-05-25': 168.97000122070312, '2022-05-26': 170.11000061035156, '2022-05-27': 171.77000427246094, '2022-05-31': 167.75, '2022-06-01': 166.49000549316406, '2022-06-02': 166.67999267578125, '2022-06-03': 164.85000610351562, '2022-06-06': 165.5399932861328, '2022-06-07': 166.55999755859375, '2022-06-08': 165.72999572753906, '2022-06-09': 162.77999877929688, '2022-06-10': 162.52000427246094, '2022-06-13': 159.74000549316406, '2022-06-14': 156.1199951171875, '2022-06-15': 157.7899932861328, '2022-06-16': 157.02999877929688, '2022-06-17': 157.05999755859375, '2022-06-21': 160.7100067138672, '2022-06-22': 162.02999877929688, '2022-06-23': 164.10000610351562, '2022-06-24': 166.1300048828125, '2022-06-27': 166.35000610351562, '2022-06-28': 164.00999450683594, '2022-06-29': 166.72999572753906, '2022-06-30': 166.66000366210938, '2022-07-01': 169.38999938964844, '2022-07-05': 169.00999450683594, '2022-07-06': 170.6999969482422, '2022-07-07': 170.36000061035156, '2022-07-08': 171.8800048828125, '2022-07-11': 170.47000122070312, '2022-07-12': 169.5, '2022-07-13': 170.10000610351562, '2022-07-14': 170.97999572753906, '2022-07-15': 171.1199951171875, '2022-07-18': 168.25999450683594, '2022-07-19': 170.05999755859375, '2022-07-20': 168.25999450683594, '2022-07-21': 168.50999450683594, '2022-07-22': 169.61000061035156, '2022-07-25': 169.85000610351562, '2022-07-26': 171.8300018310547, '2022-07-27': 171.58999633789062, '2022-07-28': 174.83999633789062, '2022-07-29': 174.9600067138672, '2022-08-01': 176.9499969482422, '2022-08-02': 175.49000549316406, '2022-08-03': 176.8300018310547, '2022-08-04': 175.8699951171875, '2022-08-05': 174.5500030517578, '2022-08-08': 173.85000610351562, '2022-08-09': 174.5, '2022-08-10': 175.94000244140625, '2022-08-11': 175.0399932861328, '2022-08-12': 177.3300018310547, '2022-08-15': 179.27999877929688, '2022-08-16': 180.32000732421875, '2022-08-17': 180.22000122070312, '2022-08-18': 180.39999389648438, '2022-08-19': 180.1699981689453, '2022-08-22': 178.44 ...

# %% [markdown]
# Calculating Statistical values and Extracting to File for GUI

# %%
'''
dict_52_week=[]
from dateutil.relativedelta import relativedelta
last_future_date=dates_val[-1]
date_1_year_back= last_future_date-relativedelta(years=1)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_1_year_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict_52_week+=[float(data_dict_close[i])]
week52high=max(dict_52_week)
week52low=min(dict_52_week)


#200 days
dict200day=[]
date_200_day_back= last_future_date-datetime.timedelta(200)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_200_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict200day+=[float(data_dict_close[i])]

#100 days
dict100day=[]
date_100_day_back= last_future_date-datetime.timedelta(100)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_100_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict100day+=[float(data_dict_close[i])]


#50 days
dict50day=[]
date_50_day_back= last_future_date-datetime.timedelta(50)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_50_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict50day+=[float(data_dict_close[i])]


print(dict200day[:5])
avg200day=sum(dict200day)/len(dict200day)
avg100day=sum(dict100day)/len(dict100day)
avg50day=sum(dict50day)/len(dict50day)

row_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]

with open('Stock_Data_LOW.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])
     writer.writerow(row_stock)
     '''
# Out:
# '\ndict_52_week=[]\nfrom dateutil.relativedelta import relativedelta\nlast_future_date=dates_val[-1]\ndate_1_year_back= last_future_date-relativedelta(years=1)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_1_year_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict_52_week+=[float(data_dict_close[i])]\nweek52high=max(dict_52_week)\nweek52low=min(dict_52_week)\n\n\n#200 days\ndict200day=[]\ndate_200_day_back= last_future_date-datetime.timedelta(200)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_200_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict200day+=[float(data_dict_close[i])]\n\n#100 days\ndict100day=[]\ndate_100_day_back= last_future_date-datetime.timedelta(100)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_100_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict100day+=[float(data_dict_close[i])]\n\n\n#50 days\ndict50day=[]\ndate_50_day_back= last_future_date-datetime.timedelta(50)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_50_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict50day+=[float(data_dict_close[i])]\n\n\nprint(dict200day[:5])\navg200day=sum(dict200day)/len(dict200day)\navg100day=sum(dict100day)/len(dict100day)\navg50day=sum(dict50day)/len(dict50day)\n\nrow_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]\n\nwith open(\'Stock_Data_LOW.csv\', \'w\', newline=\'\') as file:\n     writer = csv.writer(file)\n     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])\n     writer.writerow(row_stock)\n     '

# %% [markdown]
# How Model Is performing?

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# # **WORK IN PROGRESS!!**

# %%
print(next_prediction)
a=np.array(next_prediction)
print(a.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(next_prediction)
#       2 a=np.array(next_prediction)
#       3 print(a.shape)
#
# NameError: name 'next_prediction' is not defined

# %%
'''b=np.append(last_window[1:],next_prediction)
print(last_window.shape)
p=b.reshape(window_size_n,1)
print(p.shape)
'''
# Out:
# (25, 1)
# (25, 1)

# %%
'''
nextp= model.predict(np.array([p]))
nextdatep=next_date+datetime.timedelta(1)
d=[]+(nextp)
print(nextdatep,"|",nextp)
for i in range(7):
  p=np.append(p[1:],nextp)
  p=p.reshape(window_size_n,1)

  nextp=model.predict(np.array([p])).flatten()

  nextdatep+=datetime.timedelta(1)
  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:
    nextdatep+=datetime.timedelta(1)
  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])
  d+=(nextp)
print(p)
print(d)

'''
# Out:
# '\nnextp= model.predict(np.array([p]))\nnextdatep=next_date+datetime.timedelta(1)\nd=[]+(nextp)\nprint(nextdatep,"|",nextp)\nfor i in range(7):\n  p=np.append(p[1:],nextp)\n  p=p.reshape(window_size_n,1)\n\n  nextp=model.predict(np.array([p])).flatten()\n\n  nextdatep+=datetime.timedelta(1)\n  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:\n    nextdatep+=datetime.timedelta(1)\n  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])\n  d+=(nextp)\nprint(p)\nprint(d)\n\n'

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
print(test_predictions[1],dates_test[1])
print(df.loc['2023-09-08'])
# Out:
# 180.7636 2024-01-05 00:00:00
# Low    177.789993
# Name: 2023-09-08 00:00:00, dtype: float64
