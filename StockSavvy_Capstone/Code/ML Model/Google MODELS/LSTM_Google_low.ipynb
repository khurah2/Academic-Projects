# %% [markdown]
# Getting Data

# %%
import yfinance as yf

# %%
import yfinance as yf
data = yf.download("GOOG", period="48mo")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Data Format

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print(data.shape)
# Out:
# (1007, 6)

# %%
data.to_csv("//Users/shubham/Desktop/compsci_4zp6a_capstone/content/GOOG_demo.csv", sep='\t')

# %% [markdown]
# Data Cleaning

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['Low'][0:10]
data['Low'][-1:]
# Out:
# Date
# 2024-03-28 00:00:00-04:00    151.330002
# Name: Low, dtype: float64

# %%
data.T
# Out:
# Date       2020-03-30 00:00:00-04:00  2020-03-31 00:00:00-04:00  \
# Open                    5.625200e+01               5.736500e+01
# High                    5.758150e+01               5.876550e+01
# Low                     5.482400e+01               5.690700e+01
# Close                   5.734100e+01               5.814050e+01
# Adj Close               5.734100e+01               5.814050e+01
# Volume                  5.148200e+07               4.972800e+07
#
# Date       2020-04-01 00:00:00-04:00  2020-04-02 00:00:00-04:00  \
# Open                    5.610000e+01               5.491300e+01
# High                    5.648450e+01               5.634300e+01
# Low                     5.487250e+01               5.482000e+01
# Close                   5.528100e+01               5.604200e+01
# Adj Close               5.528100e+01               5.604200e+01
# Volume                  4.688400e+07               3.929800e+07
#
# Date       2020-04-03 00:00:00-04:00  2020-04-06 00:00:00-04:00  \
# Open                    5.595075e+01               5.690000e+01
# High                    5.617700e+01               5.973300e+01
# Low                     5.399050e+01               5.654700e+01
# Close                   5.489400e+01               5.934600e+01
# Adj Close               5.489400e+01               5.934600e+01
# Volume                  4.626800e+07               5.329400e+07
#
# Date       2020-04-07 00:00:00-04:00  2020-04-08 00:00:00-04:00  \
# Open                    6.105000e+01               6.032500e+01
# High                    6.125000e+01               6.095350e+01
# Low                     5.911150e+01               5.940800e+01
# Close                   5.932550e+01               6.051400e+01
# Adj Close               5.932550e+01               6.051400e+01
# Volume                  4.774600e+07               3.950200e+07
#
# Date       2020-04-09 00:00:00-04:00  2020-04-13 00:00:00-04:00  ...  \
# Open                    6.120400e+01               6.045900e+01  ...
# High                    6.127850e+01               6.102550e+01  ...
# Low                     5.983675e+01               5.937990e+01  ...
# Close                   6.057250e+01               6.087800e+01  ...
# Adj Close               6.057250e+01               6.087800e+01  ...
# Volume                  4.350800e+07               3.479600e+07  ...
#
# Date       2024-03-15 00:00:00-04:00  2024-03-18 00:00:00-04:00  \
# Open                    1.434100e+02               1.493700e+02
# High                    1.443400e+02               1.529300e+02
# Low                     1.411300e+02               1.481400e+02
# Close                   1.421700e+02               1.484800e+02
# Adj Close               1.421700e+02               1.484800e+02
# Volume                  4.102590e+07               4.767670e+07
#
# Date       2024-03-19 00:00:00-04:00  2024-03-20 00:00:00-04:00  \
# Open                    1.489800e+02               1.487900e+02
# High                    1.496200e+02               1.497600e+02
# Low                     1.470100e+02               1.476650e+02
# Close                   1.479200e+02               1.496800e+02
# Adj Close               1.479200e+02               1.496800e+02
# Volume                  1.774840e+07               1.773000e+07
#
# Date       2024-03-21 00:00:00-04:00  2024-03-22 00:00:00-04:00  \
# Open                    1.503200e+02               1.502400e+02
# High                    1.513050e+02               1.525600e+02
# Low                     1.480100e+02               1.500900e+02
# Close                   1.487400e+02               1.517700e+02
# Adj Close               1.487400e+02               1.517700e+02
# Volume                  1.984390e+07               1.922630e+07
#
# Date       2024-03-25 00:00:00-04:00  2024-03-26 00:00:00-04:00  \
# Open                    1.509500e+02               1.512400e+02
# High                    1.514560e+02               1.532000e+02
# Low                     1.488000e+02               1.510300e+02
# Close                   1.511500e+02               1.517000e+02
# Adj Close               1.511500e+02               1.517000e+02
# Volume                  1.511470e+07               1.931270e+07
#
# Date       2024-03-27 00:00:00-04:00  2024-03-28 00:00:00-04:00
# Open                    1.521450e+02               1.520000e+02
# High                    1.526900e+02               1.526700e+02
# Low                     1.501300e+02               1.513300e+02
# Close                   1.519400e+02               1.522600e+02
# Adj Close               1.519400e+02               1.522600e+02
# Volume                  1.662200e+07               2.110560e+07
#
# [6 rows x 1007 columns]

# %%
import numpy
import pandas as pd
import csv
from datetime import datetime

with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/content/GOOG_demo.csv', newline='') as f:
    reader = csv.reader(f)
    data_list = list(reader)
   
data_list_clean=[]
list_clean=[]
k=0
print(str(data_list[0][0]))
for i in data_list[1:]:
  list_clean+=[str(i[0]).split("\t")]
  
for j in list_clean:
    
  date=(j[0][:10])
   
  a=[date]+[float(j[1])]+[float(j[2])]+[float(j[3])]+[float(j[4])]+[float(j[5])]+[float(j[6])]
  data_list_clean+=[a]
   

print(len(data_list))
print(len(data_list_clean))
# Out:
# Date	Open	High	Low	Close	Adj Close	Volume
# 1008
# 1007

# %%
df=pd.DataFrame(data_list_clean[1:],columns=data_list[0][0].split("\t"))
print(df.dtypes)
df_fil=df[['Date','Low']]

print(df_fil[:10])
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date        Low
# 0  2020-03-31  56.907001
# 1  2020-04-01  54.872501
# 2  2020-04-02  54.820000
# 3  2020-04-03  53.990501
# 4  2020-04-06  56.547001
# 5  2020-04-07  59.111500
# 6  2020-04-08  59.408001
# 7  2020-04-09  59.836750
# 8  2020-04-13  59.379902
# 9  2020-04-14  61.846500

# %%
print(data_list_clean)
# Out:
# [['2020-03-30', 56.25199890136719, 57.58150100708008, 54.82400131225586, 57.340999603271484, 57.340999603271484, 51482000.0], ['2020-03-31', 57.3650016784668, 58.765499114990234, 56.90700149536133, 58.140499114990234, 58.140499114990234, 49728000.0], ['2020-04-01', 56.099998474121094, 56.484500885009766, 54.872501373291016, 55.28099822998047, 55.28099822998047, 46884000.0], ['2020-04-02', 54.91299819946289, 56.34299850463867, 54.81999969482422, 56.04199981689453, 56.04199981689453, 39298000.0], ['2020-04-03', 55.950748443603516, 56.176998138427734, 53.990501403808594, 54.89400100708008, 54.89400100708008, 46268000.0], ['2020-04-06', 56.900001525878906, 59.733001708984375, 56.547000885009766, 59.34600067138672, 59.34600067138672, 53294000.0], ['2020-04-07', 61.04999923706055, 61.25, 59.11149978637695, 59.32550048828125, 59.32550048828125, 47746000
# %%
import datetime
def str_to_datetime(s):
  
  split=s.split('-')
  year,month,day=int(split[0]),int(split[1]
  ),int(split[2])
  return datetime.datetime(year=year,month=month,day=day)

df_fil['Date']=df_fil['Date'].apply(str_to_datetime)
# Out:
# /var/folders/dj/2ct0t4413vdb_zyk_9q62gs40000gn/T/ipykernel_23304/1826438051.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Date']=df_fil['Date'].apply(str_to_datetime)

# %%
df_fil['Date']
# Out:
# 0      2020-03-31
# 1      2020-04-01
# 2      2020-04-02
# 3      2020-04-03
# 4      2020-04-06
#           ...
# 1001   2024-03-22
# 1002   2024-03-25
# 1003   2024-03-26
# 1004   2024-03-27
# 1005   2024-03-28
# Name: Date, Length: 1006, dtype: datetime64[ns]

# %%
df_fil.index=df_fil.pop('Date')
print(df_fil)
# Out:
#                    Low
# Date
# 2020-03-31   56.907001
# 2020-04-01   54.872501
# 2020-04-02   54.820000
# 2020-04-03   53.990501
# 2020-04-06   56.547001
# ...                ...
# 2024-03-22  150.089996
# 2024-03-25  148.800003
# 2024-03-26  151.029999
# 2024-03-27  150.130005
# 2024-03-28  151.330002
#
# [1006 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df=df_fil
plt.plot(df.index, df['Low'])
print(df[:-10])
# Out:
#                    Low
# Date
# 2020-03-31   56.907001
# 2020-04-01   54.872501
# 2020-04-02   54.820000
# 2020-04-03   53.990501
# 2020-04-06   56.547001
# ...                ...
# 2024-03-08  134.800003
# 2024-03-11  137.070007
# 2024-03-12  138.210007
# 2024-03-13  140.009995
# 2024-03-14  141.485001
#
# [996 rows x 1 columns]

# %%
str(df_fil.index[-51])[:-9]
# Out:
# '2024-01-17'

# %% [markdown]
# Reshaping data for model

# %%
import numpy as np
window_size_n=30
startdate= str(df_fil.index[window_size_n])[:-9]
lastdate=str(df_fil.index[-1])[:-9]


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Low'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                startdate,
                                lastdate,
                                window_size_n)
windowed_df
# Out:
#     Target Date   Target-30   Target-29   Target-28   Target-27   Target-26  \
# 0    2020-05-13   56.907001   54.872501   54.820000   53.990501   56.547001
# 1    2020-05-14   54.872501   54.820000   53.990501   56.547001   59.111500
# 2    2020-05-15   54.820000   53.990501   56.547001   59.111500   59.408001
# 3    2020-05-18   53.990501   56.547001   59.111500   59.408001   59.836750
# 4    2020-05-19   56.547001   59.111500   59.408001   59.836750   59.379902
# ..          ...         ...         ...         ...         ...         ...
# 971  2024-03-22  146.419998  147.429993  148.559998  145.110001  145.554993
# 972  2024-03-25  147.429993  148.559998  145.110001  145.554993  141.880005
# 973  2024-03-26  148.559998  145.110001  145.554993  141.880005  141.520004
# 974  2024-03-27  145.110001  145.554993  141.880005  141.520004  140.800003
# 975  2024-03-28  145.554993  141.880005  141.520004  140.800003  141.910004
#
#       Target-25   Target-24   Target-23   Target-22  ...    Target-9  \
# 0     59.111500   59.408001   59.836750   59.379902  ...   66.124496
# 1     59.408001   59.836750   59.379902   61.846500  ...   65.550003
# 2     59.836750   59.379902   61.846500   62.020000  ...   64.949997
# 3     59.379902   61.846500   62.020000   62.131001  ...   66.873001
# 4     61.846500   62.020000   62.131001   63.561501  ...   67.364502
# ..          ...         ...         ...         ...  ...         ...
# 971  141.880005  141.520004  140.800003  141.910004  ...  137.070007
# 972  141.520004  140.800003  141.910004  144.009995  ...  138.210007
# 973  140.800003  141.910004  144.009995  144.789993  ...  140.009995
# 974  141.910004  144.009995  144.789993  138.740005  ...  141.485001
# 975  144.009995  144.789993  138.740005  138.500000  ...  141.130005
#
#        Target-8    Target-7    Target-6    Target-5    Target-4    Target-3  \
# 0     65.550003   64.949997   66.873001   67.364502   67.763496   68.774002
# 1     64.949997   66.873001   67.364502   67.763496   68.774002   68.857597
# 2     66.873001   67.364502   67.763496   68.774002   68.857597   68.738503
# 3     67.364502   67.763496   68.774002   68.857597   68.738503   66.419998
# 4     67.763496   68.774002   68.857597   68.738503   66.419998   66.195503
# ..          ...         ...         ...         ...         ...         ...
# 971  138.210007  140.009995  141.485001  141.130005  148.139999  147.009995
# 972  140.009995  141.485001  141.130005  148.139999  147.009995  147.664993
# 973  141.485001  141.130005  148.139999  147.009995  147.664993  148.009995
# 974  141.130005  148.139999  147.009995  147.664993  148.009995  150.089996
# 975  148.139999  147.009995  147.664993  148.009995  150.089996  148.800003
#
#        Target-2    Target-1      Target
# 0     68.857597   68.738503   66.419998
# 1     68.738503   66.419998   66.195503
# 2     66.419998   66.195503   66.949997
# 3     66.195503   66.949997   67.712502
# 4     66.949997   67.712502   68.674248
# ..          ...         ...         ...
# 971  147.664993  148.009995  150.089996
# 972  148.009995  150.089996  148.800003
# 973  150.089996  148.800003  151.029999
# 974  148.800003  151.029999  150.130005
# 975  151.029999  150.130005  151.330002
#
# [976 rows x 32 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
print(X)
# Out:
# [[[ 56.907 ]
#   [ 54.8725]
#   [ 54.82  ]
#   ...
#   [ 68.774 ]
#   [ 68.8576]
#   [ 68.7385]]
#
#  [[ 54.8725]
#   [ 54.82  ]
#   [ 53.9905]
#   ...
#   [ 68.8576]
#   [ 68.7385]
#   [ 66.42  ]]
#
#  [[ 54.82  ]
#   [ 53.9905]
#   [ 56.547 ]
#   ...
#   [ 68.7385]
#   [ 66.42  ]
#   [ 66.1955]]
#
#  ...
#
#  [[148.56  ]
#   [145.11  ]
#   [145.555 ]
#   ...
#   [148.01  ]
#   [150.09  ]
#   [148.8   ]]
#
#  [[145.11  ]
#   [145.555 ]
#   [141.88  ]
#   ...
#   [150.09  ]
#   [148.8   ]
#   [151.03  ]]
#
#  [[145.555 ]
#   [141.88  ]
#   [141.52  ]
#   ...
#   [148.8   ]
#   [151.03  ]
#   [150.13  ]]]

# %% [markdown]
# Splitting data into training validation and testing

# %%
q_85 = int(len(dates) * .85)
q_95 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_85+1], X[:q_85+1], y[:q_85+1]

dates_val, X_val, y_val = dates[q_85:q_95+1], X[q_85:q_95+1], y[q_85:q_95+1]
dates_test, X_test, y_test = dates[q_95:], X[q_95:], y[q_95:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])
print(dates_test[0])
print(dates_test[-1])


print(dates[:q_85][-1])
dates[q_85-1:][0]
# Out:
# 2024-01-19 00:00:00
# 2024-03-28 00:00:00
# 2023-08-28 00:00:00
# Timestamp('2023-08-28 00:00:00')

# %% [markdown]
# LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import layers


model = Sequential([layers.Input((window_size_n, 1)),
                    layers.LSTM(512),
                  layers.Dropout(0.001),
                    layers.Dense(512, activation='relu'),
                   # layers.Dropout(0.001),
                   layers.Dense(512, activation='relu'),
                
                    layers.Dense(512, activation='relu'),

                    layers.Dense(1)])
model.compile(loss="mse",
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=25)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/25
# 26/26 [==============================] - 3s 91ms/step - loss: 3433.0969 - mean_absolute_error: 45.0172 - val_loss: 118.6181 - val_mean_absolute_error: 10.0381
# Epoch 2/25
# 26/26 [==============================] - 2s 70ms/step - loss: 170.1825 - mean_absolute_error: 9.3425 - val_loss: 13.8123 - val_mean_absolute_error: 2.7877
# Epoch 3/25
# 26/26 [==============================] - 2s 73ms/step - loss: 8.5924 - mean_absolute_error: 2.2870 - val_loss: 15.5456 - val_mean_absolute_error: 3.5488
# Epoch 4/25
# 26/26 [==============================] - 2s 69ms/step - loss: 5.0839 - mean_absolute_error: 1.7252 - val_loss: 4.2679 - val_mean_absolute_error: 1.3821
# Epoch 5/25
# 26/26 [==============================] - 2s 75ms/step - loss: 4.3714 - mean_absolute_error: 1.5893 - val_loss: 4.2333 - val_mean_absolute_error: 1.3396
# Epoch 6/25
# 26/26 [==============================] - 2s 70ms/step - loss: 4.5320 - mean_absolute_error: 1.6418 - val_loss: 7.7940 - val_mean_absolute_error: 2.3314
# Epoch 7/25
# 26/26 [==============================] - 2s 68ms/step - loss: 5.0733 - mean_absolute_error: 1.7111 - val_loss: 6.5389 - val_mean_absolute_error: 1.8412
# Epoch 8/25
# 26/26 [==============================] - 2s 67ms/step - loss: 6.9409 - mean_absolute_error: 2.0738 - val_loss: 4.4039 - val_mean_absolute_error: 1.3882
# Epoch 9/25
# 26/26 [==============================] - 2s 68ms/step - loss: 6.5074 - mean_absolute_error: 2.0008 - val_loss: 4.1628 - val_mean_absolute_error: 1.3656
# Epoch 10/25
# 26/26 [==============================] - 2s 69ms/step - loss: 4.9100 - mean_absolute_error: 1.6958 - val_loss: 4.8610 - val_mean_absolute_error: 1.4996
# Epoch 11/25
# 26/26 [==============================] - 2s 68ms/step - loss: 4.2656 - mean_absolute_error: 1.5479 - val_loss: 10.8445 - val_mean_absolute_error: 2.8772
# Epoch 12/25
# 26/26 [==============================] - 2s 68ms/step - loss: 5.7019 - mean_absolute_error: 1.8307 - val_loss: 5.5990 - val_mean_absolute_error: 1.8090
# Epoch 13/25
# 26/26 [==============================] - 2s 67ms/step - loss: 4.3187 - mean_absolute_error: 1.5805 - val_loss: 4.0873 - val_mean_absolute_error: 1.3356
# Epoch 14/25
# 26/26 [==============================] - 2s 70ms/step - loss: 4.4157 - mean_absolute_error: 1.5686 - val_loss: 5.0919 - val_mean_absolute_error: 1.6598
# Epoch 15/25
# 26/26 [==============================] - 2s 69ms/step - loss: 4.5753 - mean_absolute_error: 1.6079 - val_loss: 6.5125 - val_mean_absolute_error: 1.8298
# Epoch 16/25
# 26/26 [==============================] - 2s 69ms/step - loss: 4.4090 - mean_absolute_error: 1.5893 - val_loss: 4.4856 - val_mean_absolute_error: 1.4040
# Epoch 17/25
# 26/26 [==============================] - 2s 68ms/step - loss: 5.1040 - mean_absolute_error: 1.7507 - val_loss: 4.0728 - val_mean_absolute_error: 1.3060
# Epoch 18/25
# 26/26 [==============================] - 2s 72ms/step - loss: 4.6702 - mean_absolute_error: 1.6418 - val_loss: 4.7861 - val_mean_absolute_error: 1.5713
# Epoch 19/25
# 26/26 [==============================] - 2s 67ms/step - loss: 4.7275 - mean_absolute_error: 1.6617 - val_loss: 4.0723 - val_mean_absolute_error: 1.3056
# Epoch 20/25
# 26/26 [==============================] - 2s 68ms/step - loss: 4.7404 - mean_absolute_error: 1.6471 - val_loss: 4.4943 - val_mean_absolute_error: 1.4074
# Epoch 21/25
# 26/26 [==============================] - 2s 67ms/step - loss: 5.4315 - mean_absolute_error: 1.7890 - val_loss: 5.3013 - val_mean_absolute_error: 1.7255
# Epoch 22/25
# 26/26 [==============================] - 2s 68ms/step - loss: 4.8129 - mean_absolute_error: 1.6635 - val_loss: 4.0917 - val_mean_absolute_error: 1.3062
# Epoch 23/25
# 26/26 [==============================] - 2s 68ms/step - loss: 4.2896 - mean_absolute_error: 1.5540 - val_loss: 11.3114 - val_mean_absolute_error: 2.7568
# Epoch 24/25
# 26/26 [==============================] - 2s 69ms/step - loss: 4.9084 - mean_absolute_error: 1.7105 - val_loss: 8.6242 - val_mean_absolute_error: 2.2740
# Epoch 25/25
# 26/26 [==============================] - 2s 66ms/step - loss: 5.9422 - mean_absolute_error: 1.8606 - val_loss: 4.2500 - val_mean_absolute_error: 1.3464

# %% [markdown]
# How Model Perform on training data

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 26/26 [==============================] - 1s 23ms/step

# %% [markdown]
# How model performs on validation data

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 22ms/step

# %% [markdown]
# How model performs on Testing data

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

a=len(y_test)

s=0
for i in range(a):
  s+=(y_test[i]-test_predictions[i])**2

  print(dates_test[i],"  .|. ",y_test[i],"|",test_predictions[i],(y_test[i]-(y_test[i-1]),test_predictions[i]-test_predictions[i-1]))
print((s**(1/2))/a)
# Out:
# 2/2 [==============================] - 0s 28ms/step
# 2024-01-19 00:00:00   .|.  145.8 | 143.51463 (-5.529999, -5.3213196)
# 2024-01-22 00:00:00   .|.  147.58 | 145.66257 (1.7799988, 2.147934)
# 2024-01-23 00:00:00   .|.  147.19 | 146.91846 (-0.3899994, 1.2558899)
# 2024-01-24 00:00:00   .|.  149.84 | 146.44734 (2.649994, -0.4711151)
# 2024-03-14 00:00:00   .|.  141.485 | 140.6719 (1.4750061, 1.6096802)
# 2024-03-15 00:00:00   .|.  141.13 | 141.95288 (-0.35499573, 1.2809753)
# 2024-03-18 00:00:00   .|.  148.14 | 141.4432 (7.0099945, -0.5096741)
# 2024-03-19 00:00:00   .|.  147.01 | 147.75368 (-1.1300049, 6.3104706)
# 2024-03-20 00:00:00   .|.  147.665 | 146.40318 (0.6549988, -1.3504944)
# 2024-03-21 00:00:00   .|.  148.01 | 146.82513 (0.34500122, 0.4219513)
# 2024-03-22 00:00:00   .|.  150.09 | 147.22098 (2.0800018, 0.3958435)
# 2024-03-25 00:00:00   .|.  148.8 | 148.92905 (-1.2899933, 1.7080688)
# 2024-03-26 00:00:00   .|.  151.03 | 147.73872 (2.2299957, -1.1903229)
# 2024-03-27 00:00:00   .|.  150.13 | 149.61575 (-0.8999939, 1.8770294)
# 2024-03-28 00:00:00   .|.  151.33 | 148.83595 (1.199997, -0.7798004)
# 0.3957676695911944

# %% [markdown]
# Extracting Data to be used by GUI

# %%
row_list=[]
for i in range(len(train_predictions)):
  row_list+=[["GOOG",dates_train[i],train_predictions[i],y_train[i],False]]
for i in range(len(val_predictions)):
  row_list+=[["GOOG",dates_val[i],val_predictions[i],y_val[i],False]]
for i in range(len(test_predictions)):
  row_list+=[["GOOG",dates_test[i],test_predictions[i],y_test[i],True]]

print(row_list[:5])
with open('/Users/shubham/Desktop/compsci_4zp6a_capstone/Google/GOOG_Stock_ML_Low.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","date","Expected","Actual","isFuture"])
     writer.writerows(row_list)
# Out:
# [['GOOG', Timestamp('2020-05-13 00:00:00'), 68.230255, 66.42, False], ['GOOG', Timestamp('2020-05-14 00:00:00'), 65.92633, 66.1955, False], ['GOOG', Timestamp('2020-05-15 00:00:00'), 65.80475, 66.95, False], ['GOOG', Timestamp('2020-05-18 00:00:00'), 66.714386, 67.7125, False], ['GOOG', Timestamp('2020-05-19 00:00:00'), 67.47243, 68.67425, False]]

# %%
'''
from copy import deepcopy
last_window = deepcopy(X_test[-1])
last_date=dates_test[-1]
next_prediction = model.predict(np.array([last_window])).flatten()
next_prediction2= model2.predict(np.array([last_window])).flatten()
next_date=last_date+datetime.timedelta(1)
print(last_date,"|",last_window)
print(next_date ,"|" ,next_prediction, "||||",next_prediction2)

print(["1","2","3","4"][1:])
'''
# Out:
# '\nfrom copy import deepcopy\nlast_window = deepcopy(X_test[-1])\nlast_date=dates_test[-1]\nnext_prediction = model.predict(np.array([last_window])).flatten()\nnext_prediction2= model2.predict(np.array([last_window])).flatten()\nnext_date=last_date+datetime.timedelta(1)\nprint(last_date,"|",last_window)\nprint(next_date ,"|" ,next_prediction, "||||",next_prediction2)\n\nprint(["1","2","3","4"][1:])\n'

# %%
data_dict_close=dict()
for i in data_list_clean:
  data_dict_close[i[0]]=i[4]
print(data_dict_close["2023-11-16"])

72250366210938, '2020-08-04': 73.24849700927734, '2020-08-05': 73.68049621582031, '2020-08-06': 75.00499725341797, '2020-08-07': 74.72450256347656, '2020-08-10': 74.80500030517578, '2020-08-11': 74.01599884033203, '2020-08-12': 75.33100128173828, '2020-08-13': 75.92250061035156, '2020-08-14': 75.3864974975586, '2020-08-17': 75.89900207519531, '2020-08-18': 77.93000030517578, '2020-08-19': 77.37650299072266, '2020-08-20': 79.0875015258789, '2020-08-21': 79.02100372314453, '2020-08-24': 79.41000366210938, '2020-08-25': 80.41100311279297, '2020-08-26': 82.61900329589844, '2020-08-27': 81.71649932861328, '2020-08-28': 82.22049713134766, '2020-08-31': 81.70899963378906, '2020-09-01': 83.0354995727539, '2020-09-02': 86.41400146484375, '2020-09-03': 82.09200286865234, '2020-09-04': 79.552001953125, '2020-09-08': 76.61949920654297, '2020-09-09': 77.8479995727539, '2020-09-10': 76.60099792480469, '2020-09-11': 76.03600311279297, '2020-09-14': 75.96399688720703, '2020-09-15': 77.0719985961914, '2020-09-16': 76.04499816894531, '2020-09-17': 74.77649688720703, '2020-09-18': 72.99949645996094, '2020-09-21': 71 ...

# %% [markdown]
# Calculating Statistical values and Extracting to File for GUI

# %%
'''
dict_52_week=[]
from dateutil.relativedelta import relativedelta
last_future_date=dates_val[-1]
date_1_year_back= last_future_date-relativedelta(years=1)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_1_year_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict_52_week+=[float(data_dict_close[i])]
week52high=max(dict_52_week)
week52low=min(dict_52_week)


#200 days
dict200day=[]
date_200_day_back= last_future_date-datetime.timedelta(200)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_200_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict200day+=[float(data_dict_close[i])]

#100 days
dict100day=[]
date_100_day_back= last_future_date-datetime.timedelta(100)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_100_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict100day+=[float(data_dict_close[i])]


#50 days
dict50day=[]
date_50_day_back= last_future_date-datetime.timedelta(50)
for i in data_dict_close:
  if pd.to_datetime(i,format='%Y-%m-%d') >=date_50_day_back and pd.to_datetime(i,format='%Y-%m-%d')<=last_future_date:
    dict50day+=[float(data_dict_close[i])]


print(dict200day[:5])
avg200day=sum(dict200day)/len(dict200day)
avg100day=sum(dict100day)/len(dict100day)
avg50day=sum(dict50day)/len(dict50day)

row_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]

with open('Stock_Data_LOW.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])
     writer.writerow(row_stock)
     '''
# Out:
# '\ndict_52_week=[]\nfrom dateutil.relativedelta import relativedelta\nlast_future_date=dates_val[-1]\ndate_1_year_back= last_future_date-relativedelta(years=1)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_1_year_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict_52_week+=[float(data_dict_close[i])]\nweek52high=max(dict_52_week)\nweek52low=min(dict_52_week)\n\n\n#200 days\ndict200day=[]\ndate_200_day_back= last_future_date-datetime.timedelta(200)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_200_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict200day+=[float(data_dict_close[i])]\n\n#100 days\ndict100day=[]\ndate_100_day_back= last_future_date-datetime.timedelta(100)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_100_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict100day+=[float(data_dict_close[i])]\n\n\n#50 days\ndict50day=[]\ndate_50_day_back= last_future_date-datetime.timedelta(50)\nfor i in data_dict_close:\n  if pd.to_datetime(i,format=\'%Y-%m-%d\') >=date_50_day_back and pd.to_datetime(i,format=\'%Y-%m-%d\')<=last_future_date:\n    dict50day+=[float(data_dict_close[i])]\n\n\nprint(dict200day[:5])\navg200day=sum(dict200day)/len(dict200day)\navg100day=sum(dict100day)/len(dict100day)\navg50day=sum(dict50day)/len(dict50day)\n\nrow_stock=["AAPL",week52high,week52low,avg200day,avg100day,avg50day]\n\nwith open(\'Stock_Data_LOW.csv\', \'w\', newline=\'\') as file:\n     writer = csv.writer(file)\n     writer.writerow(["Name","52 Week high","52 week low","200 day average","100 day average","50 day average"])\n     writer.writerow(row_stock)\n     '

# %% [markdown]
# How Model Is performing?

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# # **WORK IN PROGRESS!!**

# %%
'''print(next_prediction)
a=np.array(next_prediction)
print(a.shape)'''
# Out:
# 'print(next_prediction)\na=np.array(next_prediction)\nprint(a.shape)'

# %%
'''b=np.append(last_window[1:],next_prediction)
print(last_window.shape)
p=b.reshape(window_size_n,1)
print(p.shape)
'''
# Out:
# 'b=np.append(last_window[1:],next_prediction)\nprint(last_window.shape)\np=b.reshape(window_size_n,1)\nprint(p.shape)\n'

# %%
'''
nextp= model.predict(np.array([p]))
nextdatep=next_date+datetime.timedelta(1)
d=[]+(nextp)
print(nextdatep,"|",nextp)
for i in range(7):
  p=np.append(p[1:],nextp)
  p=p.reshape(window_size_n,1)

  nextp=model.predict(np.array([p])).flatten()

  nextdatep+=datetime.timedelta(1)
  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:
    nextdatep+=datetime.timedelta(1)
  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])
  d+=(nextp)
print(p)
print(d)

'''
# Out:
# '\nnextp= model.predict(np.array([p]))\nnextdatep=next_date+datetime.timedelta(1)\nd=[]+(nextp)\nprint(nextdatep,"|",nextp)\nfor i in range(7):\n  p=np.append(p[1:],nextp)\n  p=p.reshape(window_size_n,1)\n\n  nextp=model.predict(np.array([p])).flatten()\n\n  nextdatep+=datetime.timedelta(1)\n  while not (nextdatep.strftime("%Y-%m-%d")) in data_dict_close:\n    nextdatep+=datetime.timedelta(1)\n  print(nextdatep,"|",nextp,data_dict_close[nextdatep.strftime("%Y-%m-%d")])\n  d+=(nextp)\nprint(p)\nprint(d)\n\n'

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
print(test_predictions[1],dates_test[1])
print(df.loc['2023-09-08'])
# Out:
# 145.66257 2024-01-22 00:00:00
# Low    135.869995
# Name: 2023-09-08 00:00:00, dtype: float64
